# %%
import pandas as pd
import datetime                                        # To handle dates
import calendar                                        # To get month
import statsmodels.formula.api as sm
import matplotlib.pylab as plt
import numpy as np
import seaborn as sns
import sklearn.metrics as metrics                      # To get regression metrics
import scipy as sp
import time                                            # To do time complexity analysis
import random
import copy
import profile
import cProfile
from sklearn.cluster import KMeans                     # perform clustering operation
# %matplotlib inline
import pandas.util.testing as tm

# %%
features_df = pd.read_csv("features.csv")
stores_df = pd.read_csv("stores.csv")
train_df = pd.read_csv("train.csv")

# %%
features_df.head()
# Out:
#    Store        Date  Temperature  ...         CPI  Unemployment  IsHoliday
# 0      1  2010-02-05        42.31  ...  211.096358         8.106      False
# 1      1  2010-02-12        38.51  ...  211.242170         8.106       True
# 2      1  2010-02-19        39.93  ...  211.289143         8.106      False
# 3      1  2010-02-26        46.63  ...  211.319643         8.106      False
# 4      1  2010-03-05        46.50  ...  211.350143         8.106      False
#
# [5 rows x 12 columns]

# %%
features_df.describe()
# Out:
#              Store  Temperature  ...          CPI  Unemployment
# count  8190.000000  8190.000000  ...  7605.000000   7605.000000
# mean     23.000000    59.356198  ...   172.460809      7.826821
# std      12.987966    18.678607  ...    39.738346      1.877259
# min       1.000000    -7.290000  ...   126.064000      3.684000
# 25%      12.000000    45.902500  ...   132.364839      6.634000
# 50%      23.000000    60.710000  ...   182.764003      7.806000
# 75%      34.000000    73.880000  ...   213.932412      8.567000
# max      45.000000   101.950000  ...   228.976456     14.313000
#
# [8 rows x 10 columns]

# %%
stores_df.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
stores_df.describe()
# Out:
#            Store           Size
# count  45.000000      45.000000
# mean   23.000000  130287.600000
# std    13.133926   63825.271991
# min     1.000000   34875.000000
# 25%    12.000000   70713.000000
# 50%    23.000000  126512.000000
# 75%    34.000000  202307.000000
# max    45.000000  219622.000000

# %%
train_df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %%
train_df.describe()
# Out:
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
seasons_dict = {
    1:"Winter",
    2:"Winter",
    3:"Spring",
    4:"Spring",
    5:"Spring",
    6:"Summer",
    7:"Summer",
    8:"Summer",
    9:"Fall",
    10:"Fall",
    11:"Fall",
    12:"Winter"
}

# %%
master_df = train_df.merge(stores_df, on='Store', how='left')
master_df = master_df.merge(features_df, on=['Store', 'Date'], how='left')

# %%
master_df.head()
# Out:
#    Store  Dept        Date  ...         CPI  Unemployment IsHoliday_y
# 0      1     1  2010-02-05  ...  211.096358         8.106       False
# 1      1     1  2010-02-12  ...  211.242170         8.106        True
# 2      1     1  2010-02-19  ...  211.289143         8.106       False
# 3      1     1  2010-02-26  ...  211.319643         8.106       False
# 4      1     1  2010-03-05  ...  211.350143         8.106       False
#
# [5 rows x 17 columns]

# %%
d = copy.deepcopy(master_df)

d1 = d["Weekly_Sales"]

print(d["Weekly_Sales"].describe())

print("Percentile less than 3% provides only negative value : ",d["Weekly_Sales"].quantile(0.003))
# Out:
# count    421570.000000
# mean      15981.258123
# std       22711.183519
# min       -4988.940000
# 25%        2079.650000
# 50%        7612.030000
# 75%       20205.852500
# max      693099.360000
# Name: Weekly_Sales, dtype: float64
# Percentile less than 3% provides only negative value :  -0.56

# %%
x = np.concatenate((d1[d["Weekly_Sales"] < 0], d1[d["Weekly_Sales"] > 0]))

plt.hist(x, density=True)

plt.xlim([-70496, 200000])
plt.xlabel('Weekly Sales Values')
plt.ylabel('Normalized Sales Values')
plt.title('Normalized distribution of sales values')
plt.show()

# %%
master_df['MarkDown1'] = master_df['MarkDown1'].fillna(0)
master_df['MarkDown2'] = master_df['MarkDown2'].fillna(0)
master_df['MarkDown3'] = master_df['MarkDown3'].fillna(0)
master_df['MarkDown4'] = master_df['MarkDown4'].fillna(0)
master_df['MarkDown5'] = master_df['MarkDown5'].fillna(0)

# Cleaning holiday columns
master_df['isHoliday'] = master_df['IsHoliday_x']
master_df = master_df.drop(columns=['IsHoliday_x', 'IsHoliday_y'])

# %%
master_df['Date'] = pd.to_datetime(master_df['Date'], format='%Y-%m-%d')
master_df['Week_Number'] = master_df['Date'].dt.week
master_df['Quarter'] = master_df['Date'].dt.quarter
master_df['Month'] = master_df['Date'].dt.month.apply(lambda x: calendar.month_abbr[x])
master_df['Season'] = (master_df['Date'].apply(lambda dt: (dt.month%12 + 3)//3)).map(seasons_dict)
master_df["Year"] = master_df["Date"].dt.year
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
master_df=master_df.sort_values(by=['Store', 'Dept', 'Year', 'Week_Number'], ascending=True)    

# Previous week sales
shifted_sales = master_df.shift(1)
master_df_new_var = master_df.join(shifted_sales[['Store', 'Dept', 'Week_Number', 'Weekly_Sales', 'Year']], rsuffix='_Lag')
master_df_new_var.loc[(master_df_new_var.Dept != master_df_new_var.Dept_Lag) |  (master_df_new_var.Store != master_df_new_var.Store_Lag), 'Weekly_Sales_Lag'] = -2

# %%
#forming categorarical variables
master_df_new_var = master_df_new_var.join(pd.get_dummies(master_df['Quarter'], prefix='Quarter'))
master_df_new_var = master_df_new_var.join(pd.get_dummies(master_df['Season'], prefix='Season'))
master_df_new_var = master_df_new_var.join(pd.get_dummies(master_df['Store'], prefix='Store'))
master_df_new_var = master_df_new_var.join(pd.get_dummies(master_df['Dept'], prefix='Dept'))
master_df_new_var = master_df_new_var.join(pd.get_dummies(master_df['Type'], prefix='Type'))
master_df_new_var = master_df_new_var.join(pd.get_dummies(master_df['Week_Number'], prefix='Week_Number'))

# %%
# Removing wrongly recorded data points
master_df_new_var = master_df_new_var.dropna()
#master_df_new_var = master_df_new_var.loc[master_df_new_var['Week_Number'] > 4]
#master_df_new_var = master_df_new_var.loc[master_df_new_var['Monthly_Sales_Lag'] > 0]
master_df_new_var = master_df_new_var.loc[master_df_new_var['Weekly_Sales_Lag'] > 0]
master_df_new_var = master_df_new_var.loc[master_df_new_var['Weekly_Sales'] > 0] #keeping points which are only positive in value for the sales

# %%
master_df_new_var.head()
# Out:
#    Store  Dept       Date  ...  Week_Number_50 Week_Number_51  Week_Number_52
# 1      1     1 2010-02-12  ...               0              0               0
# 2      1     1 2010-02-19  ...               0              0               0
# 3      1     1 2010-02-26  ...               0              0               0
# 4      1     1 2010-03-05  ...               0              0               0
# 5      1     1 2010-03-12  ...               0              0               0
#
# [5 rows x 213 columns]

# %%
master_df_new_var['MarkDown'] = master_df_new_var['MarkDown1'] + master_df_new_var['MarkDown2'] + master_df_new_var['MarkDown3'] + master_df_new_var['MarkDown4'] + master_df_new_var['MarkDown5']
master_df_new_var['MarkDown*Weekly_Sales_Lag'] = master_df_new_var['MarkDown']*master_df_new_var['Weekly_Sales_Lag']

# %%
#segregating the data
data_test = master_df_new_var[master_df_new_var.Year == 2012]
data_train = master_df_new_var[master_df_new_var.Year != 2012]

# %%
features = list(master_df_new_var)
for x in ('Quarter',
 'Month',
 'Season',
 'Year',
 'Store',
 'Dept',
 'Date',
 'Type',
 'Weekly_Sales',
 'Weekly_Sales_Lag'):
    features.remove(x)
#features

# %%
# Writing the formula
equals_to_str = ""
for i in features:
    equals_to_str = equals_to_str + str(i) + " + "

equals_to_str = str('Weekly_Sales ~ ') + equals_to_str
equals_to_str = equals_to_str[:-3] 
equals_to_str_promotion = equals_to_str + "Markdown1"

# %%
result_fullmodel = sm.ols(formula=equals_to_str, data = data_train).fit()
print("Model 1 without Promotion \n",result_fullmodel.summary())
# Out:
# Model 1 without Promotion
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           Weekly_Sales   R-squared:                       0.895
# Model:                            OLS   Adj. R-squared:                  0.895
# Method:                 Least Squares   F-statistic:                 1.301e+04
# Date:                Wed, 09 Jun 2021   Prob (F-statistic):               0.00
# Time:                        16:41:09   Log-Likelihood:            -2.9899e+06
# No. Observations:              289299   AIC:                         5.980e+06
# Df Residuals:                  289109   BIC:                         5.982e+06
# Df Model:                         189
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                 -1.854e+05   1.04e+05     -1.777      0.076    -3.9e+05    1.91e+04
# isHoliday[T.True]          3146.9942   2318.086      1.358      0.175   -1396.391    7690.379
# Size                         -0.2797      0.170     -1.647      0.100      -0.613       0.053
# Temperature                   3.5664      3.143      1.135      0.257      -2.594       9.727
# Fuel_Price                 -427.6663    126.459     -3.382      0.001    -675.522    -179.811
# MarkDown1                     0.0357      0.016      2.191      0.028       0.004       0.068
# MarkDown2                     0.0254      0.008      3.139      0.002       0.010       0.041
# MarkDown3                     0.0411      0.007      5.553      0.000       0.027       0.056
# MarkDown4                    -0.0723      0.032     -2.234      0.025      -0.136      -0.009
# MarkDown5                    -0.0268      0.013     -2.136      0.033      -0.051      -0.002
# CPI                          10.3677     19.796      0.524      0.600     -28.432      49.167
# Unemployment               -221.7133     53.176     -4.169      0.000    -325.936    -117.490
# Week_Number               -1868.2185   1043.982     -1.790      0.074   -3914.394     177.957
# Store_Lag                  -970.6005    555.516     -1.747      0.081   -2059.396     118.195
# Dept_Lag                   -113.8425     69.557     -1.637      0.102    -250.172      22.487
# Week_Number_Lag              11.4690     13.855      0.828      0.408     -15.686      38.624
# Year_Lag                    253.2197    143.745      1.762      0.078     -28.516     534.955
# Quarter_1                  -8.11e+04   4.57e+04     -1.775      0.076   -1.71e+05    8428.301
# Quarter_2                 -5.856e+04    3.3e+04     -1.776      0.076   -1.23e+05    6083.398
# Quarter_3                  -2.31e+04   1.28e+04     -1.798      0.072   -4.83e+04    2074.143
# Quarter_4                 -2.265e+04   1.28e+04     -1.763      0.078   -4.78e+04    2536.526
# Season_Spring             -9.448e+04   5.33e+04     -1.773      0.076   -1.99e+05    9978.836
# Season_Winter             -9.091e+04    5.1e+04     -1.781      0.075   -1.91e+05    9140.021
# Store_1                   -3.027e+04   1.69e+04     -1.788      0.074   -6.34e+04    2907.731
# Store_2                   -1.413e+04   7726.073     -1.828      0.068   -2.93e+04    1017.621
# Store_3                   -3.877e+04   2.12e+04     -1.833      0.067   -8.02e+04    2689.262
# Store_4                   -1.025e+04   7094.763     -1.445      0.148   -2.42e+04    3652.476
# Store_5                   -3.788e+04   2.05e+04     -1.849      0.064    -7.8e+04    2270.242
# Store_6                   -1.122e+04   5438.730     -2.063      0.039   -2.19e+04    -562.825
# Store_7                   -2.446e+04   1.36e+04     -1.798      0.072   -5.11e+04    2207.969
# Store_8                   -2.411e+04   1.23e+04     -1.955      0.051   -4.83e+04      62.475
# Store_9                   -8101.4388   2861.899     -2.831      0.005   -1.37e+04   -2492.196
# Store_10                  -2335.8106   3302.429     -0.707      0.479   -8808.479    4136.858
# Store_11                  -5383.8125   1876.205     -2.870      0.004   -9061.122   -1706.503
# Store_12                  -5234.4882   4693.335     -1.115      0.265   -1.44e+04    3964.319
# Store_13                   2401.7870    800.276      3.001      0.003     833.269    3970.305
# Store_14                  -1918.5227   1650.843     -1.162      0.245   -5154.129    1317.083
# Store_15                  -1259.7674    988.253     -1.275      0.202   -3196.715     677.180
# Store_16                  -2.009e+04   1.09e+04     -1.850      0.064   -4.14e+04    1200.124
# Store_17                  -7609.0790   5028.191     -1.513      0.130   -1.75e+04    2246.036
# Store_18                   1979.3979    566.132      3.496      0.000     869.795    3089.001
# Store_19                   2799.4517   1198.694      2.335      0.020     450.045    5148.859
# Store_20                   4288.0585   2532.272      1.693      0.090    -675.123    9251.240
# Store_21                   8473.1683   6298.417      1.345      0.179   -3871.554    2.08e+04
# Store_22                   5215.3829   2408.117      2.166      0.030     495.540    9935.226
# Store_23                   4878.2347   2144.601      2.275      0.023     674.876    9081.593
# Store_24                   7500.0010   3840.042      1.953      0.051     -26.375     1.5e+04
# Store_25                   8922.8134   6409.376      1.392      0.164   -3639.385    2.15e+04
# Store_26                  -5776.0072   3857.313     -1.497      0.134   -1.33e+04    1784.219
# Store_27                   1.132e+04   5602.626      2.021      0.043     340.954    2.23e+04
# Store_28                   1.322e+04   6294.497      2.100      0.036     879.214    2.56e+04
# Store_29                   4127.2132   1822.676      2.264      0.024     554.820    7699.607
# Store_30                  -1.965e+04   1.01e+04     -1.950      0.051   -3.94e+04      96.631
# Store_31                   1.325e+04   8672.088      1.528      0.126   -3745.186    3.02e+04
# Store_32                     1.4e+04   8798.854      1.591      0.112   -3246.248    3.12e+04
# Store_33                  -3.235e+04   1.92e+04     -1.687      0.092   -6.99e+04    5243.930
# Store_34                   3807.5162   1550.611      2.455      0.014     768.362    6846.670
# Store_35                   1.327e+04   6892.417      1.925      0.054    -240.410    2.68e+04
# Store_36                   -3.01e+04   1.64e+04     -1.831      0.067   -6.23e+04    2121.068
# Store_37                  -1.342e+04   6743.427     -1.990      0.047   -2.66e+04    -203.741
# Store_38                  -1.067e+04   7347.688     -1.453      0.146   -2.51e+04    3726.347
# Store_39                   1.572e+04   9763.768      1.610      0.107   -3413.193    3.49e+04
# Store_40                   7795.2039   4480.261      1.740      0.082    -985.984    1.66e+04
# Store_41                   2.071e+04   1.27e+04      1.632      0.103   -4167.068    4.56e+04
# Store_42                  -7312.0600   5037.509     -1.452      0.147   -1.72e+04    2561.317
# Store_43                  -6406.4810   3366.594     -1.903      0.057    -1.3e+04     191.950
# Store_44                  -6567.5964   3891.281     -1.688      0.091   -1.42e+04    1059.207
# Store_45                   2.621e+04   1.55e+04      1.690      0.091   -4181.597    5.66e+04
# Dept_1                    -6303.1064   4426.665     -1.424      0.154    -1.5e+04    2373.035
# Dept_2                    -2623.8183   4357.550     -0.602      0.547   -1.12e+04    5916.858
# Dept_3                    -7402.0990   4287.500     -1.726      0.084   -1.58e+04    1001.282
# Dept_4                    -5090.9195   4218.189     -1.207      0.227   -1.34e+04    3176.613
# Dept_5                    -5197.4196   4148.675     -1.253      0.210   -1.33e+04    2933.867
# Dept_6                    -8062.9166   4078.909     -1.977      0.048   -1.61e+04     -68.369
# Dept_7                    -4212.9716   4009.726     -1.051      0.293   -1.21e+04    3645.979
# Dept_8                    -4017.5133   3940.207     -1.020      0.308   -1.17e+04    3705.183
# Dept_9                    -5372.4971   3870.547     -1.388      0.165    -1.3e+04    2213.667
# Dept_10                   -5538.8160   3801.001     -1.457      0.145    -1.3e+04    1911.040
# Dept_11                   -5981.5211   3731.451     -1.603      0.109   -1.33e+04    1332.020
# Dept_12                   -7508.2174   3661.861     -2.050      0.040   -1.47e+04    -331.071
# Dept_13                   -3409.4668   3592.676     -0.949      0.343   -1.05e+04    3632.078
# Dept_14                   -5414.1009   3522.961     -1.537      0.124   -1.23e+04    1490.805
# Dept_16                   -5631.5999   3383.901     -1.664      0.096   -1.23e+04    1000.752
# Dept_17                   -5931.1603   3314.391     -1.790      0.074   -1.24e+04     564.954
# Dept_18                   -5722.6939   3244.573     -1.764      0.078   -1.21e+04     636.579
# Dept_19                   -7504.0259   3176.089     -2.363      0.018   -1.37e+04   -1278.979
# Dept_20                   -6492.5775   3106.096     -2.090      0.037   -1.26e+04    -404.716
# Dept_21                   -6298.9953   3036.377     -2.075      0.038   -1.23e+04    -347.780
# Dept_22                   -5555.7812   2967.400     -1.872      0.061   -1.14e+04     260.241
# Dept_23                   -3166.7553   2897.747     -1.093      0.274   -8846.260    2512.749
# Dept_24                   -6055.8506   2828.175     -2.141      0.032   -1.16e+04    -512.705
# Dept_25                   -5247.4903   2758.546     -1.902      0.057   -1.07e+04     159.184
# Dept_26                   -5509.3377   2689.088     -2.049      0.040   -1.08e+04    -238.800
# Dept_27                   -6431.3832   2619.874     -2.455      0.014   -1.16e+04   -1296.503
# Dept_28                   -6289.4226   2550.145     -2.466      0.014   -1.13e+04   -1291.209
# Dept_29                   -5621.9201   2481.084     -2.266      0.023   -1.05e+04    -759.065
# Dept_30                   -5813.6647   2411.682     -2.411      0.016   -1.05e+04   -1086.835
# Dept_31                   -5702.8697   2341.797     -2.435      0.015   -1.03e+04   -1113.013
# Dept_32                   -4819.3190   2272.554     -2.121      0.034   -9273.463    -365.175
# Dept_33                   -5016.3113   2203.337     -2.277      0.023   -9334.790    -697.833
# Dept_34                   -3610.6638   2134.071     -1.692      0.091   -7793.384     572.057
# Dept_35                   -5409.4999   2064.666     -2.620      0.009   -9456.188   -1362.812
# Dept_36                   -5416.8022   1995.312     -2.715      0.007   -9327.559   -1506.045
# Dept_37                   -5806.3552   1930.004     -3.008      0.003   -9589.109   -2023.601
# Dept_38                    3890.9455   1857.268      2.095      0.036     250.753    7531.138
# Dept_39                   -6490.1807   4599.840     -1.411      0.158   -1.55e+04    2525.378
# Dept_40                    1764.5811   1718.046      1.027      0.304   -1602.741    5131.903
# Dept_41                   -4802.1164   1648.531     -2.913      0.004   -8033.192   -1571.041
# Dept_42                   -3932.3131   1578.745     -2.491      0.013   -7026.609    -838.017
# Dept_43                   -3842.9558   5411.239     -0.710      0.478   -1.44e+04    6762.922
# Dept_44                   -4049.0255   1440.637     -2.811      0.005   -6872.634   -1225.417
# Dept_45                   -4836.6141   1376.486     -3.514      0.000   -7534.488   -2138.740
# Dept_46                   -1119.1142   1301.930     -0.860      0.390   -3670.861    1432.633
# Dept_47                   -4589.2052   1346.429     -3.408      0.001   -7228.169   -1950.242
# Dept_48                   -4957.7026   1178.968     -4.205      0.000   -7268.447   -2646.959
# Dept_49                   -3272.3689   1097.933     -2.980      0.003   -5424.287   -1120.451
# Dept_50                   -4548.7724   1044.074     -4.357      0.000   -6595.129   -2502.415
# Dept_51                   -3848.2265    968.486     -3.973      0.000   -5746.433   -1950.020
# Dept_52                   -3305.7369    888.079     -3.722      0.000   -5046.348   -1565.126
# Dept_54                   -3748.5990    753.473     -4.975      0.000   -5225.386   -2271.812
# Dept_55                   -1443.7758    683.816     -2.111      0.035   -2784.036    -103.515
# Dept_56                   -2756.1804    615.395     -4.479      0.000   -3962.338   -1550.023
# Dept_58                   -2935.5574    485.503     -6.046      0.000   -3887.129   -1983.985
# Dept_59                   -2646.1712    414.540     -6.383      0.000   -3458.658   -1833.684
# Dept_60                   -2595.3741    352.477     -7.363      0.000   -3286.220   -1904.529
# Dept_65                    4735.8582    746.947      6.340      0.000    3271.863    6199.853
# Dept_67                    -693.8063    216.376     -3.206      0.001   -1117.897    -269.716
# Dept_71                    -895.7811    468.500     -1.912      0.056   -1814.027      22.465
# Dept_72                    7000.1801    534.001     13.109      0.000    5953.554    8046.806
# Dept_74                    1071.6751    667.566      1.605      0.108    -236.735    2380.085
# Dept_77                   -2485.0596   1361.536     -1.825      0.068   -5153.633     183.514
# Dept_78                   -1168.8021   1204.542     -0.970      0.332   -3529.671    1192.067
# Dept_79                    2783.8316   1010.264      2.756      0.006     803.742    4763.922
# Dept_80                    1369.9488   1080.105      1.268      0.205    -747.026    3486.924
# Dept_81                    2032.5034   1148.280      1.770      0.077    -218.093    4283.100
# Dept_82                    2437.4779   1217.331      2.002      0.045      51.542    4823.413
# Dept_83                     348.7027   1287.142      0.271      0.786   -2174.060    2871.465
# Dept_85                     463.7433   1425.448      0.325      0.745   -2330.096    3257.582
# Dept_87                    2386.6506   1563.436      1.527      0.127    -677.641    5450.942
# Dept_90                    7569.0503   1771.202      4.273      0.000    4097.543     1.1e+04
# Dept_91                    5844.6983   1840.538      3.176      0.001    2237.295    9452.102
# Dept_92                    1.219e+04   1910.231      6.380      0.000    8443.452    1.59e+04
# Dept_93                    5039.2010   1979.579      2.546      0.011    1159.280    8919.122
# Dept_94                    6350.0513   2049.449      3.098      0.002    2333.188    1.04e+04
# Dept_95                    1.171e+04   2118.278      5.529      0.000    7560.939    1.59e+04
# Dept_96                    3885.4969   2188.464      1.775      0.076    -403.833    8174.826
# Dept_97                    3656.9620   2257.137      1.620      0.105    -766.964    8080.888
# Dept_98                    2630.9302   2327.115      1.131      0.258   -1930.150    7192.011
# Dept_99                    -410.6551   2437.392     -0.168      0.866   -5187.876    4366.566
# Type_A                    -4.869e+04   2.71e+04     -1.798      0.072   -1.02e+05    4376.073
# Type_B                    -7.268e+04    4.1e+04     -1.771      0.077   -1.53e+05    7753.119
# Type_C                    -6.403e+04   3.62e+04     -1.767      0.077   -1.35e+05    6991.598
# Week_Number_1             -1.651e+04   9375.816     -1.760      0.078   -3.49e+04    1870.745
# Week_Number_2              -1.57e+04   8347.770     -1.881      0.060   -3.21e+04     661.664
# Week_Number_3             -1.325e+04   7301.117     -1.815      0.070   -2.76e+04    1057.526
# Week_Number_4             -1.174e+04   6255.977     -1.877      0.061    -2.4e+04     518.231
# Week_Number_5             -7310.2914   5212.189     -1.403      0.161   -1.75e+04    2905.455
# Week_Number_6             -1.041e+04   6447.487     -1.615      0.106    -2.3e+04    2227.152
# Week_Number_7             -5188.0456   3087.685     -1.680      0.093   -1.12e+04     863.731
# Week_Number_8             -5017.5122   2043.265     -2.456      0.014   -9022.254   -1012.770
# Week_Number_9              -832.3853    991.014     -0.840      0.401   -2774.746    1109.975
# Week_Number_10             -349.7557    131.424     -2.661      0.008    -607.344     -92.168
# Week_Number_11             1866.1558   1120.963      1.665      0.096    -330.901    4063.212
# Week_Number_12             3339.4428   2160.692      1.546      0.122    -895.453    7574.339
# Week_Number_13            -1.579e+04   9496.870     -1.663      0.096   -3.44e+04    2822.187
# Week_Number_14            -1.504e+04   8448.052     -1.780      0.075   -3.16e+04    1518.069
# Week_Number_15            -1.359e+04   7398.783     -1.837      0.066   -2.81e+04     909.470
# Week_Number_16            -1.072e+04   6353.502     -1.687      0.092   -2.32e+04    1735.829
# Week_Number_17            -1.039e+04   5308.519     -1.957      0.050   -2.08e+04      14.736
# Week_Number_18            -6217.4143   4260.023     -1.459      0.144   -1.46e+04    2132.113
# Week_Number_19            -6335.3379   3216.606     -1.970      0.049   -1.26e+04     -30.880
# Week_Number_20            -4078.4756   2176.624     -1.874      0.061   -8344.597     187.646
# Week_Number_21            -1379.8936   1144.225     -1.206      0.228   -3622.543     862.756
# Week_Number_22             4454.0761   2145.329      2.076      0.038     249.290    8658.862
# Week_Number_23             4830.6513   3183.832      1.517      0.129   -1409.571    1.11e+04
# Week_Number_24             7119.9846   4222.769      1.686      0.092   -1156.526    1.54e+04
# Week_Number_25             8580.6427   5264.105      1.630      0.103   -1736.856    1.89e+04
# Week_Number_26            -2.399e+04   1.38e+04     -1.734      0.083   -5.11e+04    3121.929
# Week_Number_27            -2.286e+04   1.28e+04     -1.787      0.074   -4.79e+04    2210.800
# Week_Number_28            -2.158e+04   1.17e+04     -1.837      0.066   -4.46e+04    1448.071
# Week_Number_29            -1.941e+04   1.07e+04     -1.813      0.070   -4.04e+04    1570.865
# Week_Number_30            -1.762e+04   9660.471     -1.824      0.068   -3.66e+04    1314.244
# Week_Number_31            -1.412e+04   8616.701     -1.639      0.101    -3.1e+04    2764.491
# Week_Number_32            -1.404e+04   7574.276     -1.854      0.064   -2.89e+04     804.705
# Week_Number_33            -1.146e+04   6536.418     -1.753      0.080   -2.43e+04    1354.495
# Week_Number_34            -9911.3472   5497.181     -1.803      0.071   -2.07e+04     862.976
# Week_Number_35            -8091.5735   4455.755     -1.816      0.069   -1.68e+04     641.582
# Week_Number_36            -9289.8936   5730.009     -1.621      0.105   -2.05e+04    1940.765
# Week_Number_37            -5200.0721   2371.401     -2.193      0.028   -9847.952    -552.192
# Week_Number_38            -3023.1668   1333.398     -2.267      0.023   -5636.589    -409.744
# Week_Number_39             -937.7939    301.131     -3.114      0.002   -1528.003    -347.585
# Week_Number_40             1973.3046    772.901      2.553      0.011     458.441    3488.169
# Week_Number_41             1863.4515   1811.163      1.029      0.304   -1686.377    5413.280
# Week_Number_42             4677.6228   2855.570      1.638      0.101    -919.215    1.03e+04
# Week_Number_43             6444.2850   3897.368      1.653      0.098   -1194.448    1.41e+04
# Week_Number_44             9091.3764   4937.820      1.841      0.066    -586.614    1.88e+04
# Week_Number_45             1.012e+04   5986.658      1.691      0.091   -1612.385    2.19e+04
# Week_Number_46             1.154e+04   7029.150      1.642      0.101   -2235.343    2.53e+04
# Week_Number_47             1.636e+04   5752.321      2.844      0.004    5087.368    2.76e+04
# Week_Number_48             8125.1736   6864.510      1.184      0.237   -5329.075    2.16e+04
# Week_Number_49             1.636e+04   7904.658      2.070      0.038     866.813    3.19e+04
# Week_Number_50             1.821e+04   8945.167      2.036      0.042     677.544    3.57e+04
# Week_Number_51             2.458e+04   9985.654      2.462      0.014    5011.475    4.42e+04
# Week_Number_52             6445.2699   8720.475      0.739      0.460   -1.06e+04    2.35e+04
# MarkDown                      0.0606      0.007      8.643      0.000       0.047       0.074
# Weekly_Sales_Lag              0.8555      0.001    806.915      0.000       0.853       0.858
# MarkDown:Weekly_Sales_Lag -3.052e-06   3.69e-08    -82.670      0.000   -3.12e-06   -2.98e-06
# ==============================================================================
# Omnibus:                   448686.335   Durbin-Watson:                   2.539
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      10881684835.750
# Skew:                           8.490   Prob(JB):                         0.00
# Kurtosis:                     952.972   Cond. No.                     1.88e+21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.03e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
unique_dept_values = master_df_new_var.Dept.unique() #getting unique values of store by department type
unique_data_string = []    #creating null list
mark = []

#creating unique list containing names of department for creating labels for the graph
for counter in range(0, len(unique_dept_values)):
    if unique_dept_values[counter] == 38 or unique_dept_values[counter] == 92 or unique_dept_values[counter] == 95:
        unique_data_string.append("Dept-" + str(unique_dept_values[counter]))
        mark.append("+")
    else:
        unique_data_string.append("")
        mark.append("o")


mean_sales = []   #creating list of mean sales
for intcounter in unique_dept_values:
    mean_sales.append(data_train[data_train["Dept_" + str(intcounter)]==1]["Weekly_Sales"].mean()) #estimating mean sales for store by department type

#creating formula for regression
equals_to_str_dept = "Weekly_Sales ~ Weekly_Sales_Lag + isHoliday + Temperature + Type_A + Type_B + Type_C+ Week_Number_50 + Week_Number_51 + " 
for intcounter in range(len(unique_dept_values)):
    if intcounter != len(unique_dept_values)-1:
        equals_to_str_dept = equals_to_str_dept + "Dept_" + str(unique_dept_values[intcounter]) + " + "
    else:
        equals_to_str_dept = equals_to_str_dept + "Dept_" + str(unique_dept_values[intcounter])

#running regression with relevant variables and all the department type to calculate which department type impacts the weekly sales the most
result_with_dpt = sm.ols(formula=equals_to_str_dept, data = data_train).fit()
result_list = result_with_dpt.tvalues #calculating t value to zero in on important parameters
result_tstat = []
 
for intcounter in range(9,90):
    result_tstat.append(result_list[intcounter]) #getting t stat value for each department and store type
 
fig, ax = plt.subplots()
ax.scatter(result_tstat, mean_sales) #making a scatter plot to highlight high performing departments
plt.xlabel('T- statistics')
plt.ylabel('Mean Weekly Sales')
plt.title('Mean weekly sales by department type')

for i, txt in enumerate(unique_data_string):
    ax.annotate(txt, (result_tstat[i],mean_sales[i])) #identifying the high performing graph and labelling them

# %%
ax= sns.barplot(x="Store", y="Weekly_Sales",  data=master_df_new_var)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=7)
plt.tight_layout()
plt.show()

# %%
sns.barplot(x="Year", y="Weekly_Sales", hue="Type", data=master_df)

# %%
df_corr = master_df.corr()
ax=df_corr[['Weekly_Sales']].plot(kind='bar')
plt.xlabel('Attribute')
plt.ylabel('Correlation')
plt.title('Correlation of Weekly sales with other variables')
plt.tight_layout()
plt.show()

# %%
heat_df= master_df[['Store','Dept','Weekly_Sales']]
heat_map=heat_df.groupby(['Store','Dept']).mean()
heat_map.reset_index(inplace=True)
heat_map=heat_map.pivot('Store','Dept','Weekly_Sales')
fig, ax = plt.subplots(figsize=(20,7))
sns.heatmap(heat_map, cmap="YlGnBu", ax=ax)
plt.xlabel('Department')
plt.ylabel('Store')
plt.title('A heatmap indicating average sales of various departments')
plt.tight_layout()
plt.show()

# %%
#function to draw pair plot
def drawpairplot(total_clusters, data, blnDraw):
    kmeans=KMeans(n_clusters=total_clusters).fit(data)
    data['Cluster']=kmeans.labels_
    if blnDraw:
        sns.pairplot(data,hue='Cluster')

df = copy.deepcopy(master_df)   #creating a copy of the data frame to not change the master data frame
df["Type"] = df['Type'].map({'A': int(0), 'B': int(1), 'C': int(2)}) #giving numberical values to different store types

nClusters = range(2,7)  #defining a range of clusters between 2 and 7
rel_cols=['Type', 'Weekly_Sales'] #defining the relevant columns in the data set on which clustering needs to run

sumDistances=[]

#calculating SSE
for n in nClusters:
    kmeans=KMeans(n_clusters=n).fit(df[rel_cols])
    sumDistances.append(kmeans.inertia_) #Proxy for SSE

# Plotting the elbow graph
plt.plot(nClusters,sumDistances,'-')
plt.xlabel('nClusters')
plt.ylabel('Sum Of Distances')
plt.show()

# %%
print("As we see a slight kink at cluster = 3. Assuming cluster as 3 and plotting the pair plot")
drawpairplot(3,df[rel_cols],True) #drawing pair plot for 3 clusters
# Out:
# As we see a slight kink at cluster = 3. Assuming cluster as 3 and plotting the pair plot
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
features = ['isHoliday', 'Temperature', 'Weekly_Sales_Lag']#, 'Size', 'MarkDown5', 'master_df_new_var']
features.extend(master_df_new_var.columns[master_df_new_var.columns.str.startswith('Type')])
features.remove('Type')

# %%
equals_to_str = ""

for i in features:
    equals_to_str = equals_to_str + str(i) + " + "

equals_to_str = str('Weekly_Sales ~ ') + equals_to_str
equals_to_str = equals_to_str  + 'Week_Number_50 + Week_Number_51+ Dept_95 + Dept_92+ Dept_38'
equals_to_str_withpromotion = equals_to_str  + '+ MarkDown*Weekly_Sales_Lag'

# %%
result_withoutpromotion = sm.ols(formula=equals_to_str, data = data_train).fit()
print("Model 1 without Promotion \n",result_withoutpromotion.summary())
# Out:
# Model 1 without Promotion
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           Weekly_Sales   R-squared:                       0.879
# Model:                            OLS   Adj. R-squared:                  0.879
# Method:                 Least Squares   F-statistic:                 2.099e+05
# Date:                Wed, 09 Jun 2021   Prob (F-statistic):               0.00
# Time:                        16:52:29   Log-Likelihood:            -3.0104e+06
# No. Observations:              289299   AIC:                         6.021e+06
# Df Residuals:                  289288   BIC:                         6.021e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           247.3962     42.690      5.795      0.000     163.725     331.067
# isHoliday[T.True]  -845.5337     55.780    -15.158      0.000    -954.860    -736.207
# Temperature           9.9790      0.837     11.928      0.000       8.339      11.619
# Weekly_Sales_Lag      0.9067      0.001   1185.741      0.000       0.905       0.908
# Type_A              698.9296     24.786     28.199      0.000     650.351     747.509
# Type_B                5.6130     24.101      0.233      0.816     -41.624      52.850
# Type_C             -457.1464     40.400    -11.316      0.000    -536.328    -377.964
# Week_Number_50     2363.1381    106.518     22.185      0.000    2154.366    2571.911
# Week_Number_51     6783.5677    106.467     63.715      0.000    6574.895    6992.240
# Dept_95            5074.3453    128.151     39.597      0.000    4823.173    5325.518
# Dept_92            5462.1660    129.366     42.223      0.000    5208.612    5715.720
# Dept_38            4289.9392    126.057     34.032      0.000    4042.872    4537.007
# ==============================================================================
# Omnibus:                   322653.403   Durbin-Watson:                   2.644
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       8837920688.647
# Skew:                           4.081   Prob(JB):                         0.00
# Kurtosis:                     859.224   Cond. No.                     1.78e+20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.25e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
result_withpromotion = sm.ols(formula=equals_to_str_withpromotion, data = data_train).fit()
print("Model 1 with Promotion \n",result_withpromotion.summary())
# Out:
# Model 1 with Promotion
#                              OLS Regression Results
# ==============================================================================
# Dep. Variable:           Weekly_Sales   R-squared:                       0.883
# Model:                            OLS   Adj. R-squared:                  0.883
# Method:                 Least Squares   F-statistic:                 1.822e+05
# Date:                Wed, 09 Jun 2021   Prob (F-statistic):               0.00
# Time:                        16:52:53   Log-Likelihood:            -3.0052e+06
# No. Observations:              289299   AIC:                         6.010e+06
# Df Residuals:                  289286   BIC:                         6.010e+06
# Df Model:                          12
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    37.1945     42.183      0.882      0.378     -45.482     119.872
# isHoliday[T.True]          -852.3239     57.564    -14.806      0.000    -965.148    -739.500
# Temperature                   9.8274      0.826     11.902      0.000       8.209      11.446
# Weekly_Sales_Lag              0.9295      0.001   1186.239      0.000       0.928       0.931
# Type_A                      523.3284     24.537     21.328      0.000     475.236     571.421
# Type_B                      -72.7195     23.749     -3.062      0.002    -119.267     -26.172
# Type_C                     -413.4144     39.680    -10.419      0.000    -491.187    -335.642
# Week_Number_50             2256.6944    104.664     21.561      0.000    2051.556    2461.832
# Week_Number_51             6673.0064    104.573     63.812      0.000    6468.046    6877.967
# Dept_95                    4280.9141    126.114     33.945      0.000    4033.733    4528.095
# Dept_92                    4809.7484    127.235     37.802      0.000    4560.371    5059.125
# Dept_38                    3575.8496    124.011     28.835      0.000    3332.792    3818.907
# MarkDown                      0.0938      0.002     52.599      0.000       0.090       0.097
# MarkDown:Weekly_Sales_Lag -3.881e-06   3.77e-08   -102.926      0.000   -3.95e-06   -3.81e-06
# ==============================================================================
# Omnibus:                   403272.905   Durbin-Watson:                   2.609
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      10351804901.642
# Skew:                           6.666   Prob(JB):                         0.00
# Kurtosis:                     929.606   Cond. No.                     3.60e+24
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.49e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
data_test = pd.concat([data_test, result_withoutpromotion.predict(data_test).rename("predicted_values_withoutpromotion")], axis=1)
print('The accuracy of the model is', round((1-(metrics.median_absolute_error(data_test.predicted_values_withoutpromotion, data_test.Weekly_Sales)/data_test.Weekly_Sales.median()))*100, 2), '%.(in the test dataset)')
data_train = pd.concat([data_train, result_withoutpromotion.predict(data_train).rename("predicted_values_withoutpromotion")], axis=1)
print('The accuracy of the model is', round((1-(metrics.median_absolute_error(data_train.predicted_values_withoutpromotion, data_train.Weekly_Sales)/data_train.Weekly_Sales.median()))*100, 2), '%.(in the train dataset)')
# Out:
# The accuracy of the model is 84.56 %.(in the test dataset)
# The accuracy of the model is 84.53 %.(in the train dataset)

# %%
pred_val = result_withoutpromotion.fittedvalues.copy()
true_val = data_train['Weekly_Sales'].values.copy()
residual = true_val - pred_val
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Error in Predicted Value', fontsize = 18)
plt.ylabel('Predicted Value', fontsize = 18)
plt.title("Residual plot (for Train Data)", fontsize = 20)
_ = ax.scatter(pred_val, residual)

# %%
fig, ax = plt.subplots(figsize=(15,5))
_, (__, ___, r) = sp.stats.probplot(residual, plot=ax, fit=True)
#r**2

# %%
pred_val = result_withpromotion.fittedvalues.copy()
true_val = data_train['Weekly_Sales'].values.copy()
residual = true_val - pred_val
fig, ax = plt.subplots(figsize=(15,5))
plt.xlabel('Error in Predicted Value', fontsize = 18)
plt.ylabel('Predicted Value', fontsize = 18)
plt.title("Comparison of Predicted Values VS Error (for Test Data)", fontsize = 20)
_ = ax.scatter(pred_val, residual)

# %%
fig, ax = plt.subplots(figsize=(15,5))
_, (__, ___, r) = sp.stats.probplot(residual, plot=ax, fit=True)
#r**2

# %%
data_test["predicted_values_withoutpromotion"] = result_withoutpromotion.predict(data_test)
data_test["predicted_values_withpromotion"] = result_withoutpromotion.predict(data_test)

actual_sales = data_test.groupby("Dept").mean()["Weekly_Sales"]
predicted_sales_withoutpromotion = data_test.groupby("Dept").mean()["predicted_values_withoutpromotion"]
#data_test.to_csv("predictedvsactual.csv")

# %%
plt.scatter(data_test['Weekly_Sales'], data_test['predicted_values_withpromotion'])
plt.xlabel('Actual Value', fontsize = 18)
plt.ylabel('Predicted Value', fontsize = 18)
plt.title("Scatter plot of Actual Value VS Predicted Value", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Scatter plot of Actual Value VS Predicted Value')

# %%
# To calculate L2 norm
def normDiff (x, y, ord=2): 
    return np.linalg.norm (x - y, ord=ord) / np.linalg.norm (y, ord=ord) #Normalized by the "length" of y.

# %%
# Define batchwise regression
def run_ols_batchwise(DataFrame, Formula):
    df_length = len(DataFrame.index)
    
    # Getting an initial estimate for beta coefficients
    DataFrame.index = range(df_length)
    DataFrame['batch_number'] = DataFrame.index % int(df_length/10000)
    result = sm.ols(Formula, DataFrame.loc[DataFrame.batch_number == 1]).fit()
    
    # Extracting relevant columns out of formula
    variables = Formula.split('+')
    variable1 = variables[0].split('~')[1]
    variables.remove(variables[0])
    variables.insert(0, variable1)
    variables.insert(0, 'Constant')
    variables = [x.strip(' ') for x in variables]

    # Preparing the data for interative linear regression
    DataFrame['Constant'] = 1
    X = np.array(DataFrame[variables])
    y = np.array(DataFrame.Weekly_Sales)
    beta_t = np.array(result.params)
    phi = 2/max(result.eigenvals)
    
    for t in range(int(df_length)):
        
        #print("Iteration1:", beta_t)
        #y_data_array = DataFrame[(100*t):(100*(t + 1))]['Weekly_Sales']
        #x_data_array = DataFrame.loc[(100*t):(100*(t + 1))-1, variables]
        #yT = np.array(y_data_array)
        #xT = np.array(x_data_array)
        
        xT = X[t,:]
        yT = y[t]
        
        #print(xT.shape)
        #print(yT.shape)
        #print(beta_t.shape)
        
        #delta_t = phi * xT.T.dot(yT -xT.dot(beta_t))
        
        delta_t = phi * xT.dot(yT -xT.T.dot(beta_t))
        
        beta_t = beta_t + delta_t
    
    return beta_t

# %%
# Function calling
batchwise_beta = run_ols_batchwise(data_test, equals_to_str)
print('The mean error (MSE) in predicting the coeficient is ', round(normDiff(batchwise_beta, result_withoutpromotion.params), 4)*100, '%')
# Out:
# The mean error (MSE) in predicting the coeficient is  85.76 %

# %%
# To measure the time taken to execute the function
def measureTime(fun,arg1):
    nTimes=10
    times=np.zeros(nTimes)
    for i in range(nTimes):
        startTime = time.time()    
        fun(arg1)
        endTime = time.time()
        times[i]=endTime-startTime
    return np.mean(times)

# %%
def predict(total_obs):
    X = []
    y = []
    for obs in range(total_obs):
        i=random.randint(0, len(data_test))
        x=pd.DataFrame(data_test.iloc[i,:]).T[["isHoliday", "Temperature", "Weekly_Sales_Lag", "Type_A", "Type_B", "Type_C", "Week_Number_50", "Week_Number_51", "Dept_95", "Dept_92", "Dept_38"]]
        x=x.astype(int)
        X.append(x)
        predicted_value = result_withoutpromotion.predict(x)
        y.append(predicted_value)
    return (X, y)

# %%
N = 11                                                   # Number of variables is set constant
M = np.geomspace(start=15,stop=1000,num=5,dtype=int)    # Varying the number of observations

times = np.zeros(len(M))
for (i, m) in enumerate(M):
    t = measureTime(predict, m)
    times[i] = t

# %%
# Creating Benchmarks
linearTime = [times[0]/M[0]*m for m in M]
lognTime = [times[0]/(np.log(M[0]))*(np.log(m)) for m in M]
nlognTime = [times[0]/(M[0]*np.log(M[0]))*(m*np.log(m)) for m in M]
loglognTime = [times[0]/(np.log(M[0])*np.log(M[0]))*(np.log(m)*np.log(m)) for m in M]

# Plotting the result
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.loglog (M, times, 'k-',linewidth=3,label="Code")

ax1.loglog (M, linearTime, 'b--',label="Linear")
ax1.loglog (M, lognTime, 'g--',label="Log(m)")
ax1.loglog (M, nlognTime, 'r--',label="m*Log(m)")

plt.xlabel('Number of Independent Variables')
plt.ylabel('Time (Seconds)')
plt.title("Comparison of Time plot with linear, log(n), and n*log(n) plots")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
profile.run('print(predict(20));print(\'=\' * 100)')
# Out:
# ([        isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 103017          0           81              2332  ...        0        0        0
#
# [1 rows x 11 columns],        isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 40960          0           76              2235  ...        0        0        0
#
# [1 rows x 11 columns],        isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 25857          0           73              2817  ...        0        0        0
#
# [1 rows x 11 columns],        isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 98041          0           48              1173  ...        0        0        0
#
# [1 rows x 11 columns],        isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 89815          0           63              2005  ...        0        0        0
#
# [1 rows x 11 columns],        isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 62156          0           82                57  ...        0        0        0
#
# [1 rows x 11 columns],        isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 26797          0           89             60578  ...        0        0        0
#
# [1 rows x 11 columns],        isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 15142          1           48             37321  ...        0        0        0
#
# [1 rows x 11 columns],        isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 73872          0           44               474  ...        0        0        0
#
# [1 rows x 11 columns],         isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 120229          1           84               385  ...        0        0        0
#
# [1 rows x 11 columns],       isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 8529          0           81              2004  ...        0        0        0
#
# [1 rows x 11 columns],        isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 36028          0           36              8671  ...        0        0        0
#
# [1 rows x 11 columns],         isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 120885          0           77               167  ...        0        0        0
#
# [1 rows x 11 columns],         isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 106829          1           88                34  ...        0        0        0
#
# [1 rows x 11 columns],        isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 84058          0           34              2391  ...        0        0        0
#
# [1 rows x 11 columns],         isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 123601          0           81             28356  ...        0        0        0
#
# [1 rows x 11 columns],        isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 11331          0           81             33909  ...        0        0        0
#
# [1 rows x 11 columns],        isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 20000          0           63               778  ...        0        0        0
#
# [1 rows x 11 columns],         isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 107951          0           56               619  ...        0        0        0
#
# [1 rows x 11 columns],        isHoliday  Temperature  Weekly_Sales_Lag  ...  Dept_95  Dept_92  Dept_38
# 55196          0           48              2461  ...        0        0        0
#
# [1 rows x 11 columns]], [103017    3869.007754
# dtype: float64, 40960    3731.164643
# dtype: float64, 25857    3535.600992
# dtype: float64, 98041    2488.855803
# dtype: float64, 89815    3392.900928
# dtype: float64, 62156    1122.965095
# dtype: float64, 26797    56066.211954
# dtype: float64, 15142    34418.118425
# dtype: float64, 73872    1121.851584
# dtype: float64, 120229    132.021983
# dtype: float64, 8529    2878.298973
# dtype: float64, 36028    9167.421396
# dtype: float64, 120885    710.045985
# dtype: float64, 106829   -146.30809
# dtype: float64, 84058    2760.1743
# dtype: float64, 123601    26308.463956
# dtype: float64, 11331    32499.35369
# dtype: float64, 20000    1587.08365
# dtype: float64, 107951    910.308746
# dtype: float64, 55196    3656.664194
# dtype: float64])
# ====================================================================================================
#          1724093 function calls (1705373 primitive calls) in 5.676 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        20    0.000    0.000    0.000    0.000 :0(__getitem__)
#      1160    0.002    0.000    0.002    0.000 :0(__new__)
#     11300    0.021    0.000    0.021    0.000 :0(_abc_instancecheck)
#        20    0.000    0.000    0.000    0.000 :0(_abc_subclasscheck)
#       140    0.000    0.000    0.000    0.000 :0(_filters_mutated)
#        20    0.000    0.000    0.000    0.000 :0(_getframe)
#         5    0.000    0.000    0.000    0.000 :0(acquire)
#       140    0.000    0.000    0.000    0.000 :0(add)
#      2190    0.009    0.000    0.042    0.000 :0(all)
#      2085    0.011    0.000    0.047    0.000 :0(any)
#      7245    0.011    0.000    0.011    0.000 :0(append)
#       560    0.004    0.000    0.004    0.000 :0(arange)
#        20    0.000    0.000    0.000    0.000 :0(argsort)
# 21640/20460    0.073    0.000    0.113    0.000 :0(array)
#        20    0.001    0.000    0.001    0.000 :0(array_to_datetime)
#       840    0.006    0.000    0.006    0.000 :0(astype)
#        20    0.000    0.000    0.000    0.000 :0(astype_intsafe)
#        20    0.000    0.000    0.000    0.000 :0(bit_length)
#      1420    0.002    0.000    0.002    0.000 :0(callable)
#       280    0.001    0.000    0.001    0.000 :0(checknull)
#        40    0.001    0.000    0.002    0.000 :0(clean_index_list)
#       400    0.000    0.000    0.000    0.000 :0(clear)
#       220    0.009    0.000    0.009    0.000 :0(compile)
#       520    0.002    0.000    0.002    0.000 :0(copy)
#        40    0.000    0.000    0.000    0.000 :0(datetime_data)
#      2360    0.013    0.000    0.013    0.000 :0(empty)
#       160    0.000    0.000    0.000    0.000 :0(encode)
#        75    0.000    0.000    0.000    0.000 :0(endswith)
#       320    0.001    0.000    0.001    0.000 :0(ensure_int64)
#      4660    0.006    0.000    0.006    0.000 :0(ensure_object)
#       280    0.001    0.000    0.001    0.000 :0(ensure_platform_int)
#        20    0.000    0.000    0.000    0.000 :0(eq)
#       220    0.001    0.000    0.059    0.000 :0(eval)
#         1    0.000    0.000    5.676    5.676 :0(exec)
#       900    0.002    0.000    0.002    0.000 :0(extend)
#        80    0.000    0.000    0.000    0.000 :0(fileno)
#       560    0.002    0.000    0.002    0.000 :0(fill)
#       700    0.002    0.000    0.002    0.000 :0(format)
#        20    0.000    0.000    0.000    0.000 :0(fromkeys)
#      2640    0.006    0.000    0.007    0.000 :0(get)
#        20    0.000    0.000    0.000    0.000 :0(get_blkno_placements)
#       200    0.005    0.000    0.007    0.000 :0(get_indexer)
#       300    0.003    0.000    0.003    0.000 :0(get_loc)
#        80    0.001    0.000    0.001    0.000 :0(get_terminal_size)
# 217880/217840    0.268    0.000    0.277    0.000 :0(getattr)
#      2320    0.004    0.000    0.004    0.000 :0(geterrobj)
#         4    0.000    0.000    0.000    0.000 :0(getpid)
#        21    0.000    0.000    0.000    0.000 :0(getrandbits)
#        40    0.000    0.000    0.000    0.000 :0(getvalue)
#     30460    0.056    0.000    0.057    0.000 :0(hasattr)
# 12500/12140    0.015    0.000    0.016    0.000 :0(hash)
#        60    0.000    0.000    0.000    0.000 :0(id)
# 1400/1260    0.017    0.000    0.354    0.000 :0(implement_array_function)
#        20    0.000    0.000    0.000    0.000 :0(index)
#      4640    0.009    0.000    0.009    0.000 :0(infer_datetimelike_array)
#       680    0.016    0.000    0.025    0.000 :0(infer_dtype)
#        80    0.000    0.000    0.000    0.000 :0(insert)
#        20    0.000    0.000    0.000    0.000 :0(invert)
#       380    0.001    0.000    0.001    0.000 :0(is_bool)
#        20    0.000    0.000    0.000    0.000 :0(is_datetime_array)
#      2760    0.003    0.000    0.003    0.000 :0(is_float)
#      2220    0.003    0.000    0.003    0.000 :0(is_integer)
#       500    0.001    0.000    0.001    0.000 :0(is_iterator)
#     10260    0.037    0.000    0.079    0.000 :0(is_list_like)
#      4300    0.007    0.000    0.007    0.000 :0(is_scalar)
#    304984    0.647    0.000    1.210    0.000 :0(isinstance)
#        60    0.001    0.000    0.001    0.000 :0(isnaobj)
#     93320    0.119    0.000    0.119    0.000 :0(issubclass)
#      1640    0.003    0.000    0.003    0.000 :0(item_from_zerodim)
#       820    0.001    0.000    0.001    0.000 :0(items)
#       760    0.001    0.000    0.002    0.000 :0(iter)
#       260    0.001    0.000    0.001    0.000 :0(join)
#       340    0.001    0.000    0.001    0.000 :0(keys)
# 88945/74865    0.157    0.000    0.193    0.000 :0(len)
#       980    0.001    0.000    0.001    0.000 :0(ljust)
#        20    0.000    0.000    0.000    0.000 :0(lower)
#       240    0.009    0.000    0.015    0.000 :0(map_infer)
#        20    0.001    0.000    0.001    0.000 :0(map_infer_mask)
#      2860    0.012    0.000    0.023    0.000 :0(max)
#       320    0.010    0.000    0.019    0.000 :0(maybe_convert_objects)
#        20    0.000    0.000    0.000    0.000 :0(maybe_dispatch_ufunc_to_dunder_op)
#        20    0.000    0.000    0.000    0.000 :0(min)
#       260    0.003    0.000    0.003    0.000 :0(nanmax)
#        40    0.000    0.000    0.001    0.000 :0(next)
#       400    0.004    0.000    0.004    0.000 :0(or_)
#      1320    0.003    0.000    0.003    0.000 :0(pop)
#         2    0.000    0.000    1.612    0.806 :0(print)
#       140    0.000    0.000    0.000    0.000 :0(ravel)
#      1260    0.017    0.000    0.017    0.000 :0(reduce)
#        20    0.000    0.000    0.000    0.000 :0(remove)
#        20    0.000    0.000    0.000    0.000 :0(repeat)
#      1020    0.001    0.000    0.001    0.000 :0(replace)
#      4920    0.012    0.000    0.012    0.000 :0(reshape)
#      1040    0.002    0.000    0.002    0.000 :0(rjust)
#       100    0.001    0.000    0.001    0.000 :0(round)
#      1160    0.003    0.000    0.003    0.000 :0(seterrobj)
#         1    0.000    0.000    0.000    0.000 :0(setprofile)
#       240    0.000    0.000    0.000    0.000 :0(slice_len)
#       120    0.006    0.000    0.088    0.001 :0(sorted)
#      3500    0.006    0.000    0.006    0.000 :0(split)
#        60    0.000    0.000    0.000    0.000 :0(startswith)
#       760    0.008    0.000    0.039    0.000 :0(sum)
#        20    0.000    0.000    0.000    0.000 :0(take)
#       140    0.002    0.000    0.002    0.000 :0(take_1d_int64_int64)
#        60    0.001    0.000    0.001    0.000 :0(take_1d_object_object)
#        20    0.000    0.000    0.000    0.000 :0(take_2d_axis1_object_object)
#       840    0.002    0.000    0.002    0.000 :0(transpose)
#       200    0.000    0.000    0.000    0.000 :0(update)
#      4820    0.007    0.000    0.007    0.000 :0(upper)
#       160    0.000    0.000    0.000    0.000 :0(values)
#       120    0.000    0.000    0.000    0.000 :0(view)
#        40    0.000    0.000    0.000    0.000 :0(write)
#        20    0.001    0.000    0.001    0.000 :0(writelines)
#       240    0.001    0.000    0.001    0.000 :0(zeros)
#        20    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(all)
#       220    0.002    0.000    0.293    0.001 <__array_function__ internals>:2(any)
#        20    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(argsort)
#        60    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(array_equal)
#        60    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(atleast_1d)
#        40    0.000    0.000    0.035    0.001 <__array_function__ internals>:2(atleast_2d)
#        40    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(can_cast)
#        60    0.000    0.000    0.010    0.000 <__array_function__ internals>:2(concatenate)
#       680    0.004    0.000    0.008    0.000 <__array_function__ internals>:2(copyto)
#       100    0.001    0.000    0.008    0.000 <__array_function__ internals>:2(delete)
#        20    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(dot)
#        20    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#        20    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(prod)
#        20    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(repeat)
#        20    0.000    0.000    0.038    0.002 <__array_function__ internals>:2(vstack)
#     10640    0.067    0.000    0.118    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#         1    0.003    0.003    4.063    4.063 <ipython-input-126-a1135e583ebd>:1(predict)
#     221/1    0.001    0.000    5.675    5.675 <string>:1(<module>)
#       180    0.001    0.000    0.004    0.000 __init__.py:111(_maybe_match_name)
#       200    0.005    0.000    0.152    0.001 __init__.py:243(dispatch_to_series)
#       200    0.001    0.000    0.003    0.000 __init__.py:307(_align_method_SERIES)
#        20    0.000    0.000    0.023    0.001 __init__.py:359(wrapper)
#       200    0.003    0.000    0.176    0.001 __init__.py:386(wrapper)
#       200    0.004    0.000    0.131    0.001 __init__.py:433(_align_method_FRAME)
#       200    0.002    0.000    0.005    0.000 __init__.py:524(_should_reindex_frame_op)
#       200    0.005    0.000    0.318    0.002 __init__.py:634(f)
#       220    0.001    0.000    0.006    0.000 __init__.py:88(get_op_result_name)
# 5760/4580    0.015    0.000    0.072    0.000 _asarray.py:14(asarray)
#      4820    0.139    0.000    0.194    0.000 _asarray.py:221(require)
#      4820    0.018    0.000    0.025    0.000 _asarray.py:298(<setcomp>)
#      4580    0.011    0.000    0.018    0.000 _asarray.py:86(asanyarray)
#        40    0.000    0.000    0.000    0.000 _dtype.py:178(_datetime_metadata_str)
#     10760    0.015    0.000    0.015    0.000 _dtype.py:24(_kind_name)
#     10760    0.017    0.000    0.028    0.000 _dtype.py:307(_name_includes_bit_suffix)
#     10760    0.066    0.000    0.125    0.000 _dtype.py:321(_name_get)
#        20    0.000    0.000    0.000    0.000 _methods.py:37(_amax)
#        20    0.000    0.000    0.001    0.000 _methods.py:45(_sum)
#      1080    0.004    0.000    0.017    0.000 _methods.py:53(_any)
#        80    0.000    0.000    0.001    0.000 _methods.py:56(_all)
#        20    0.000    0.000    0.002    0.000 _mixins.py:89(reshape)
#      1160    0.006    0.000    0.008    0.000 _ufunc_config.py:132(geterr)
#      1160    0.011    0.000    0.024    0.000 _ufunc_config.py:32(seterr)
#       580    0.001    0.000    0.001    0.000 _ufunc_config.py:429(__init__)
#       580    0.003    0.000    0.016    0.000 _ufunc_config.py:433(__enter__)
#       580    0.003    0.000    0.014    0.000 _ufunc_config.py:438(__exit__)
#       200    0.001    0.000    0.001    0.000 _validators.py:112(_check_for_invalid_keys)
#       200    0.002    0.000    0.005    0.000 _validators.py:125(validate_kwargs)
#       140    0.000    0.000    0.001    0.000 _validators.py:208(validate_bool_kwarg)
#       200    0.001    0.000    0.002    0.000 _validators.py:33(_check_for_default_values)
#     11300    0.026    0.000    0.047    0.000 abc.py:137(__instancecheck__)
#        20    0.000    0.000    0.000    0.000 abc.py:141(__subclasscheck__)
#        20    0.000    0.000    0.005    0.000 accessor.py:183(__get__)
#       220    0.004    0.000    0.016    0.000 algorithms.py:1511(_get_take_nd_function)
#       220    0.008    0.000    0.057    0.000 algorithms.py:1640(take_nd)
#        20    0.000    0.000    0.004    0.000 api.py:109(_get_combined_index)
#       220    0.002    0.000    0.003    0.000 api.py:161(union_indexes)
#        20    0.000    0.000    0.004    0.000 api.py:65(get_objs_combined_axis)
#        20    0.000    0.000    0.000    0.000 api.py:91(<listcomp>)
#        20    0.000    0.000    0.000    0.000 api.py:95(_get_distinct_objs)
#        20    0.000    0.000    0.004    0.000 array_ops.py:119(na_arithmetic_op)
#        20    0.001    0.000    0.010    0.000 array_ops.py:195(comparison_op)
#       400    0.003    0.000    0.009    0.000 array_ops.py:256(na_logical_op)
#       400    0.012    0.000    0.073    0.000 array_ops.py:297(logical_op)
#       800    0.004    0.000    0.025    0.000 array_ops.py:315(fill_bool)
#       200    0.001    0.000    0.001    0.000 array_ops.py:362(get_array_op)
#       420    0.002    0.000    0.002    0.000 array_ops.py:404(maybe_upcast_datetimelike_array)
#        20    0.000    0.000    0.000    0.000 base.py:102(_freeze)
#       180    0.002    0.000    0.005    0.000 base.py:1032(__iter__)
#       100    0.000    0.000    0.000    0.000 base.py:109(__setattr__)
#       600    0.001    0.000    0.001    0.000 base.py:1175(name)
#       280    0.001    0.000    0.005    0.000 base.py:1182(name)
#        20    0.000    0.000    0.000    0.000 base.py:1193(_validate_names)
#        20    0.000    0.000    0.000    0.000 base.py:1213(_get_names)
#        20    0.000    0.000    0.001    0.000 base.py:1216(_set_names)
#        20    0.000    0.000    0.002    0.000 base.py:1246(set_names)
#       280    0.000    0.000    0.000    0.000 base.py:1378(nlevels)
#       100    0.001    0.000    0.001    0.000 base.py:1646(is_unique)
#       200    0.001    0.000    0.002    0.000 base.py:1685(is_boolean)
#       300    0.001    0.000    0.002    0.000 base.py:1755(is_floating)
#       240    0.002    0.000    0.006    0.000 base.py:1841(is_object)
#       100    0.000    0.000    0.000    0.000 base.py:1994(holds_integer)
#        60    0.000    0.000    0.002    0.000 base.py:2000(inferred_type)
#        20    0.000    0.000    0.000    0.000 base.py:2007(is_all_dates)
#     33520    0.126    0.000    0.718    0.000 base.py:256(is_dtype)
#       300    0.002    0.000    0.012    0.000 base.py:2854(get_loc)
#   960/400    0.063    0.000    0.425    0.001 base.py:293(__new__)
#       200    0.004    0.000    0.077    0.000 base.py:2960(get_indexer)
#        40    0.000    0.000    0.001    0.000 base.py:3118(_validate_positional_slice)
#        20    0.000    0.000    0.001    0.000 base.py:3197(_convert_listlike_indexer)
#        20    0.000    0.000    0.001    0.000 base.py:3219(_convert_arr_indexer)
#        20    0.000    0.000    0.000    0.000 base.py:3250(_convert_list_indexer)
#       100    0.000    0.000    0.000    0.000 base.py:3278(_can_reindex)
#       120    0.002    0.000    0.049    0.000 base.py:3294(reindex)
#      1620    0.002    0.000    0.002    0.000 base.py:3873(_values)
#       540    0.002    0.000    0.002    0.000 base.py:3899(_get_engine_target)
#      1140    0.010    0.000    0.016    0.000 base.py:4039(__contains__)
#      2280    0.015    0.000    0.030    0.000 base.py:4086(__getitem__)
#       240    0.001    0.000    0.018    0.000 base.py:4123(_can_hold_identifiers_and_holds_name)
#     16780    0.089    0.000    0.151    0.000 base.py:413(find)
#        20    0.000    0.000    0.029    0.001 base.py:4136(append)
#        20    0.000    0.000    0.000    0.000 base.py:4159(<setcomp>)
#        20    0.000    0.000    0.028    0.001 base.py:4164(_concat)
#        20    0.000    0.000    0.000    0.000 base.py:4168(<listcomp>)
#      1900    0.009    0.000    0.053    0.000 base.py:4199(equals)
#       440    0.001    0.000    0.001    0.000 base.py:424(<genexpr>)
#       100    0.000    0.000    0.009    0.000 base.py:4278(identical)
#       100    0.000    0.000    0.001    0.000 base.py:4618(_should_fallback_to_positional)
#       100    0.001    0.000    0.002    0.000 base.py:4626(_get_values_for_loc)
#       620    0.005    0.000    0.008    0.000 base.py:463(_simple_new)
#        20    0.000    0.000    0.026    0.001 base.py:4703(get_indexer_for)
#       200    0.002    0.000    0.007    0.000 base.py:4720(_maybe_promote)
#       300    0.002    0.000    0.005    0.000 base.py:4979(_maybe_cast_indexer)
#       200    0.001    0.000    0.004    0.000 base.py:498(_shallow_copy)
#       120    0.000    0.000    0.000    0.000 base.py:4988(_validate_indexer)
#      1900    0.005    0.000    0.008    0.000 base.py:520(is_)
#       100    0.001    0.000    0.011    0.000 base.py:5209(delete)
#       100    0.002    0.000    0.062    0.001 base.py:5262(drop)
#       900    0.002    0.000    0.002    0.000 base.py:544(_reset_identity)
#       340    0.003    0.000    0.006    0.000 base.py:554(_engine)
#      5180    0.018    0.000    0.144    0.000 base.py:5562(ensure_index)
#       340    0.000    0.000    0.000    0.000 base.py:561(<lambda>)
#       120    0.000    0.000    0.001    0.000 base.py:5626(ensure_has_len)
#        60    0.001    0.000    0.002    0.000 base.py:5638(trim_front)
#       240    0.000    0.000    0.000    0.000 base.py:5643(<genexpr>)
#        60    0.000    0.000    0.000    0.000 base.py:5644(<listcomp>)
#       280    0.003    0.000    0.030    0.000 base.py:5653(default_index)
#      2720    0.012    0.000    0.041    0.000 base.py:5659(maybe_extract_name)
#     10860    0.025    0.000    0.038    0.000 base.py:567(__len__)
#       320    0.002    0.000    0.015    0.000 base.py:5675(_maybe_cast_with_dtype)
#       320    0.004    0.000    0.028    0.000 base.py:5729(_maybe_cast_data_without_dtype)
#        20    0.000    0.000    0.000    0.000 base.py:573(__array__)
#        20    0.000    0.000    0.001    0.000 base.py:5800(_try_convert_to_int_array)
#       520    0.001    0.000    0.001    0.000 base.py:590(dtype)
#        20    0.000    0.000    0.000    0.000 base.py:626(shape)
#       620    0.001    0.000    0.001    0.000 base.py:637(ndim)
#        20    0.000    0.000    0.000    0.000 base.py:669(size)
#        20    0.000    0.000    0.001    0.000 base.py:701(take)
#        20    0.000    0.000    0.000    0.000 base.py:723(_assert_take_fillable)
#        20    0.000    0.000    0.003    0.000 base.py:793(copy)
#       100    0.001    0.000    0.074    0.001 base.py:909(format)
#       100    0.002    0.000    0.074    0.001 base.py:931(_format_with_header)
#        40    0.001    0.000    0.024    0.001 base.py:942(<listcomp>)
#       240    0.001    0.000    0.001    0.000 blocks.py:111(_simple_new)
#       120    0.002    0.000    0.043    0.000 blocks.py:1238(take_nd)
#      7340    0.070    0.000    0.369    0.000 blocks.py:124(__init__)
#      7340    0.012    0.000    0.012    0.000 blocks.py:135(_check_ndim)
#      8760    0.046    0.000    0.142    0.000 blocks.py:176(_consolidate_key)
#        40    0.000    0.000    0.000    0.000 blocks.py:180(is_view)
#        20    0.000    0.000    0.000    0.000 blocks.py:190(external_values)
#        20    0.000    0.000    0.000    0.000 blocks.py:2008(_holder)
#      1940    0.002    0.000    0.002    0.000 blocks.py:201(internal_values)
#        20    0.000    0.000    0.000    0.000 blocks.py:2029(array_values)
#        20    0.000    0.000    0.007    0.000 blocks.py:2032(iget)
#        20    0.000    0.000    0.001    0.000 blocks.py:2048(__init__)
#        20    0.000    0.000    0.000    0.000 blocks.py:2056(_maybe_coerce_values)
#       700    0.002    0.000    0.010    0.000 blocks.py:207(array_values)
#       860    0.003    0.000    0.014    0.000 blocks.py:213(get_values)
#        20    0.000    0.000    0.000    0.000 blocks.py:229(fill_value)
#     18520    0.021    0.000    0.021    0.000 blocks.py:233(mgr_locs)
#      7540    0.047    0.000    0.251    0.000 blocks.py:237(mgr_locs)
#      5000    0.026    0.000    0.339    0.000 blocks.py:2396(__init__)
#       220    0.001    0.000    0.050    0.000 blocks.py:244(make_block)
#       960    0.005    0.000    0.027    0.000 blocks.py:256(make_block_same_class)
#      6600    0.125    0.000    1.197    0.000 blocks.py:2677(get_block_type)
#      6380    0.056    0.000    1.636    0.000 blocks.py:2723(make_block)
#       320    0.002    0.000    0.003    0.000 blocks.py:2750(_extend_blocks)
#       240    0.001    0.000    0.001    0.000 blocks.py:287(_slice)
#       240    0.002    0.000    0.005    0.000 blocks.py:292(getitem_block)
#      5100    0.007    0.000    0.007    0.000 blocks.py:311(shape)
#     17040    0.021    0.000    0.021    0.000 blocks.py:315(dtype)
#      5120    0.008    0.000    0.008    0.000 blocks.py:319(iget)
#        20    0.000    0.000    0.007    0.000 blocks.py:340(apply)
#       220    0.002    0.000    0.056    0.000 blocks.py:350(_split_op_result)
#       260    0.005    0.000    0.045    0.000 blocks.py:514(astype)
#       240    0.001    0.000    0.010    0.000 blocks.py:675(copy)
#       480    0.002    0.000    0.002    0.000 build.py:207(_column_combinations)
#       240    0.000    0.000    0.000    0.000 build.py:209(<listcomp>)
#       240    0.002    0.000    0.003    0.000 build.py:223(_subterm_column_combinations)
#       240    0.009    0.000    0.019    0.000 build.py:259(_build_subterm)
#        20    0.000    0.000    0.000    0.000 build.py:347(_factors_memorize)
#       200    0.001    0.000    0.002    0.000 build.py:42(_max_allowed_dim)
#        20    0.000    0.000    0.000    0.000 build.py:437(_examine_factor_types)
#        20    0.000    0.000    0.000    0.000 build.py:571(_make_subterm_infos)
#       220    0.006    0.000    1.461    0.007 build.py:61(_eval_factor)
#        20    0.001    0.000    0.005    0.000 build.py:638(design_matrix_builders)
#        40    0.004    0.000    0.039    0.001 build.py:739(_build_design_matrix)
#        40    0.000    0.000    0.000    0.000 build.py:775(__init__)
#       480    0.002    0.000    0.005    0.000 build.py:782(check)
#        20    0.012    0.001    1.872    0.094 build.py:797(build_design_matrices)
#       220    0.000    0.000    0.000    0.000 build.py:877(<lambda>)
#       220    0.001    0.000    0.002    0.000 build.py:878(<lambda>)
#        20    0.000    0.000    0.000    0.000 build.py:908(<listcomp>)
#       820    0.009    0.000    0.028    0.000 cast.py:1187(maybe_castable)
#      4940    0.074    0.000    0.422    0.000 cast.py:1201(maybe_infer_to_datetimelike)
#        20    0.000    0.000    0.001    0.000 cast.py:1244(try_datetime)
#       640    0.013    0.000    0.077    0.000 cast.py:1310(maybe_cast_to_datetime)
#        20    0.001    0.000    0.006    0.000 cast.py:1448(find_common_type)
#        40    0.000    0.000    0.000    0.000 cast.py:1472(<genexpr>)
#       140    0.000    0.000    0.000    0.000 cast.py:1478(<genexpr>)
#        40    0.000    0.000    0.000    0.000 cast.py:1487(<genexpr>)
#        40    0.000    0.000    0.000    0.000 cast.py:1489(<genexpr>)
#        40    0.000    0.000    0.001    0.000 cast.py:1494(<genexpr>)
#       540    0.006    0.000    0.012    0.000 cast.py:1570(construct_1d_object_array_from_listlike)
#       360    0.001    0.000    0.002    0.000 cast.py:1595(construct_1d_ndarray_preserving_na)
#        20    0.000    0.000    0.001    0.000 cast.py:1630(maybe_cast_to_integer_array)
#       240    0.006    0.000    0.031    0.000 cast.py:442(maybe_promote)
#       240    0.001    0.000    0.007    0.000 cast.py:598(_ensure_dtype_type)
#       280    0.003    0.000    0.025    0.000 cast.py:88(maybe_convert_platform)
#        20    0.001    0.000    0.004    0.000 cast.py:898(astype_nansafe)
#        20    0.000    0.000    0.001    0.000 categorical.py:151(_categorical_shape_fix)
#        20    0.001    0.000    0.022    0.001 categorical.py:308(categorical_to_int)
#       840    0.004    0.000    0.014    0.000 common.py:1025(is_datetime_or_timedelta_dtype)
#        20    0.000    0.000    0.002    0.000 common.py:1064(is_numeric_v_string_like)
#        40    0.000    0.000    0.008    0.000 common.py:1123(is_datetimelike_v_numeric)
#       840    0.004    0.000    0.068    0.000 common.py:1180(needs_i8_conversion)
#       360    0.001    0.000    0.006    0.000 common.py:1223(is_numeric_dtype)
#        80    0.000    0.000    0.001    0.000 common.py:1265(is_string_like_dtype)
#        80    0.000    0.000    0.000    0.000 common.py:1293(<lambda>)
#      1520    0.007    0.000    0.022    0.000 common.py:1296(is_float_dtype)
#      1440    0.012    0.000    0.064    0.000 common.py:1330(is_bool_dtype)
#     16460    0.091    0.000    0.280    0.000 common.py:1460(is_extension_array_dtype)
#      2520    0.007    0.000    0.010    0.000 common.py:149(cast_scalar_indexer)
#       560    0.002    0.000    0.003    0.000 common.py:150(ensure_python_int)
#       500    0.002    0.000    0.007    0.000 common.py:1509(is_complex_dtype)
#       240    0.001    0.000    0.010    0.000 common.py:1541(_is_dtype)
#      3520    0.011    0.000    0.022    0.000 common.py:1565(_get_dtype)
#     17620    0.094    0.000    0.236    0.000 common.py:1600(_is_dtype_type)
#      7400    0.036    0.000    0.062    0.000 common.py:1733(pandas_dtype)
#        20    0.000    0.000    0.000    0.000 common.py:176(not_none)
#     13700    0.019    0.000    0.019    0.000 common.py:178(classes)
#        60    0.000    0.000    0.000    0.000 common.py:180(<genexpr>)
#     13700    0.032    0.000    0.048    0.000 common.py:180(<lambda>)
#      3920    0.006    0.000    0.006    0.000 common.py:183(classes_and_not_datetimelike)
#      3920    0.011    0.000    0.017    0.000 common.py:188(<lambda>)
#       280    0.001    0.000    0.003    0.000 common.py:190(all_none)
#       560    0.001    0.000    0.001    0.000 common.py:194(<genexpr>)
#      9920    0.043    0.000    0.222    0.000 common.py:194(is_object_dtype)
#        40    0.000    0.000    0.001    0.000 common.py:197(any_not_none)
#       160    0.000    0.000    0.000    0.000 common.py:201(<genexpr>)
#       980    0.011    0.000    0.033    0.000 common.py:218(asarray_tuplesafe)
#      6640    0.047    0.000    0.146    0.000 common.py:224(is_sparse)
#       100    0.001    0.000    0.005    0.000 common.py:241(index_labels_to_array)
#       500    0.002    0.000    0.010    0.000 common.py:274(maybe_iterable_to_list)
#       440    0.001    0.000    0.002    0.000 common.py:283(is_null_slice)
#      1140    0.003    0.000    0.004    0.000 common.py:329(apply_if_callable)
#       660    0.002    0.000    0.003    0.000 common.py:348(is_datetime64_dtype)
#      8440    0.032    0.000    0.225    0.000 common.py:381(is_datetime64tz_dtype)
#      2500    0.010    0.000    0.020    0.000 common.py:422(is_timedelta64_dtype)
#      9420    0.035    0.000    0.273    0.000 common.py:456(is_period_dtype)
#      8560    0.032    0.000    0.249    0.000 common.py:492(is_interval_dtype)
#       220    0.003    0.000    0.207    0.001 common.py:50(new_method)
#     10200    0.039    0.000    0.244    0.000 common.py:530(is_categorical_dtype)
#       160    0.001    0.000    0.010    0.000 common.py:566(is_string_dtype)
#       160    0.000    0.000    0.008    0.000 common.py:595(condition)
#        60    0.000    0.000    0.007    0.000 common.py:598(is_excluded_dtype)
#       240    0.001    0.000    0.007    0.000 common.py:603(<genexpr>)
#       920    0.004    0.000    0.010    0.000 common.py:608(is_dtype_equal)
#        20    0.000    0.000    0.000    0.000 common.py:67(_expand_user)
#      2180    0.010    0.000    0.035    0.000 common.py:696(is_integer_dtype)
#       740    0.003    0.000    0.011    0.000 common.py:750(is_signed_integer_dtype)
#       640    0.003    0.000    0.009    0.000 common.py:806(is_unsigned_integer_dtype)
#      2120    0.006    0.000    0.008    0.000 common.py:905(is_datetime64_any_dtype)
#      1220    0.008    0.000    0.038    0.000 common.py:97(is_bool_indexer)
#        20    0.000    0.000    0.000    0.000 common.py:97(stringify_path)
#       220    0.001    0.000    0.071    0.000 compat.py:34(call_and_wrap_exc)
#        20    0.000    0.000    0.007    0.000 concat.py:110(concat_compat)
#        40    0.000    0.000    0.000    0.000 concat.py:128(is_nonempty)
#        20    0.000    0.000    0.000    0.000 concat.py:139(<listcomp>)
#        40    0.000    0.000    0.000    0.000 concat.py:144(<genexpr>)
#        20    0.000    0.000    0.000    0.000 concat.py:147(<setcomp>)
#        60    0.000    0.000    0.001    0.000 concat.py:148(<genexpr>)
#        40    0.000    0.000    0.000    0.000 concat.py:174(__init__)
#        20    0.001    0.000    0.005    0.000 concat.py:29(get_dtype_kinds)
#        20    0.002    0.000    0.041    0.002 concat.py:295(__init__)
#        20    0.001    0.000    0.007    0.000 concat.py:31(concatenate_block_managers)
#        20    0.000    0.000    0.001    0.000 concat.py:380(<listcomp>)
#        20    0.001    0.000    0.031    0.002 concat.py:456(get_result)
#        20    0.000    0.000    0.002    0.000 concat.py:49(<listcomp>)
#        20    0.000    0.000    0.000    0.000 concat.py:511(_get_result_dim)
#        20    0.000    0.000    0.034    0.002 concat.py:517(_get_new_axes)
#        20    0.000    0.000    0.034    0.002 concat.py:520(<listcomp>)
#        20    0.000    0.000    0.004    0.000 concat.py:524(_get_comb_axis)
#        60    0.000    0.000    0.001    0.000 concat.py:525(_combine_concat_plans)
#        20    0.000    0.000    0.030    0.001 concat.py:534(_get_concat_axis)
#        20    0.000    0.000    0.000    0.000 concat.py:567(<listcomp>)
#        20    0.000    0.000    0.000    0.000 concat.py:584(_maybe_check_integrity)
#        20    0.000    0.000    0.029    0.001 concat.py:591(_concat_indexes)
#        20    0.000    0.000    0.073    0.004 concat.py:70(concat)
#        40    0.001    0.000    0.002    0.000 concat.py:87(_get_mgr_concatenation_plan)
#      3400    0.017    0.000    0.109    0.000 config.py:104(_get_option)
#        40    0.001    0.000    0.005    0.000 config.py:112(_set_option)
#      3380    0.010    0.000    0.119    0.000 config.py:232(__call__)
#        20    0.000    0.000    0.000    0.000 config.py:394(__init__)
#        20    0.000    0.000    0.003    0.000 config.py:402(__enter__)
#        20    0.000    0.000    0.001    0.000 config.py:403(<listcomp>)
#        20    0.000    0.000    0.003    0.000 config.py:408(__exit__)
#      3440    0.005    0.000    0.005    0.000 config.py:539(_select_options)
#      3440    0.013    0.000    0.019    0.000 config.py:557(_get_root)
#      6820    0.012    0.000    0.012    0.000 config.py:571(_get_deprecated_option)
#        40    0.000    0.000    0.000    0.000 config.py:587(_get_registered_option)
#      3440    0.009    0.000    0.014    0.000 config.py:598(_translate_key)
#      3380    0.009    0.000    0.015    0.000 config.py:610(_warn_if_deprecated)
#        40    0.000    0.000    0.000    0.000 config.py:792(inner)
#      3440    0.030    0.000    0.074    0.000 config.py:86(_get_single_key)
#        40    0.000    0.000    0.002    0.000 config_init.py:364(_deprecate_negative_int_max_colwidth)
#        20    0.000    0.000    0.000    0.000 console.py:53(in_interactive_session)
#        20    0.000    0.000    0.000    0.000 console.py:77(in_ipython_frontend)
#        20    0.000    0.000    0.004    0.000 console.py:8(get_console_size)
#       460    0.031    0.000    2.192    0.005 construction.py:143(init_ndarray)
#        20    0.011    0.001    0.383    0.019 construction.py:216(<listcomp>)
#        20    0.009    0.000    1.179    0.059 construction.py:225(<listcomp>)
#       220    0.006    0.000    0.537    0.002 construction.py:237(init_dict)
#       220    0.001    0.000    0.006    0.000 construction.py:274(<listcomp>)
#       220    0.001    0.000    0.002    0.000 construction.py:278(<listcomp>)
#       220    0.001    0.000    0.010    0.000 construction.py:281(<listcomp>)
#       460    0.003    0.000    0.006    0.000 construction.py:289(_prep_ndarray)
#       220    0.001    0.000    0.003    0.000 construction.py:329(_homogenize)
#      2000    0.009    0.000    0.056    0.000 construction.py:339(extract_array)
#       220    0.004    0.000    0.011    0.000 construction.py:360(extract_index)
#      1100    0.033    0.000    0.306    0.000 construction.py:390(sanitize_array)
#       460    0.003    0.000    0.055    0.000 construction.py:450(_get_axes)
#       820    0.010    0.000    0.097    0.000 construction.py:520(_try_cast)
#      1100    0.006    0.000    0.018    0.000 construction.py:580(is_empty_data)
#       220    0.004    0.000    0.224    0.001 construction.py:60(arrays_to_mgr)
#        20    0.000    0.000    0.001    0.000 contextlib.py:107(__enter__)
#        20    0.000    0.000    0.000    0.000 contextlib.py:116(__exit__)
#        20    0.000    0.000    0.000    0.000 contextlib.py:237(helper)
#        20    0.000    0.000    0.000    0.000 contextlib.py:81(__init__)
#        20    0.000    0.000    0.000    0.000 data.py:100(_is_using_pandas)
#        20    0.000    0.000    0.000    0.000 datetimelike.py:1082(freq)
#        20    0.000    0.000    0.000    0.000 datetimelike.py:464(_ndarray)
#        20    0.000    0.000    0.002    0.000 datetimelike.py:469(_from_backing_data)
#        20    0.000    0.000    0.000    0.000 datetimelike.py:491(asi8)
#        20    0.000    0.000    0.004    0.000 datetimelike.py:530(__getitem__)
#        20    0.000    0.000    0.001    0.000 datetimelike.py:564(_get_getitem_freq)
#        20    0.000    0.000    0.002    0.000 datetimes.py:215(__init__)
#        20    0.000    0.000    0.001    0.000 datetimes.py:2183(_validate_dt64_dtype)
#        20    0.000    0.000    0.000    0.000 datetimes.py:287(_simple_new)
#        20    0.000    0.000    0.000    0.000 datetimes.py:475(_box_func)
#        20    0.001    0.000    0.001    0.000 datetimes.py:477(<lambda>)
#        60    0.000    0.000    0.000    0.000 datetimes.py:479(dtype)
#        20    0.000    0.000    0.000    0.000 datetimes.py:501(tz)
#       480    0.002    0.000    0.004    0.000 desc.py:53(__hash__)
#        60    0.001    0.000    0.010    0.000 design_info.py:1014(__new__)
#        20    0.001    0.000    0.003    0.000 design_info.py:271(__init__)
#        20    0.000    0.000    0.000    0.000 design_info.py:361(<listcomp>)
#       160    0.001    0.000    0.001    0.000 design_info.py:401(column_names)
#       420    0.002    0.000    0.007    0.000 dispatch.py:11(should_extension_dispatch)
#      7680    0.035    0.000    0.207    0.000 dtypes.py:1119(is_dtype)
#      8540    0.037    0.000    0.226    0.000 dtypes.py:906(is_dtype)
#        20    0.000    0.000    0.000    0.000 eval.py:136(__init__)
#       220    0.002    0.000    0.070    0.000 eval.py:155(eval)
#        40    0.000    0.000    0.001    0.000 eval.py:168(capture)
#       440    0.001    0.000    0.001    0.000 eval.py:42(__init__)
#   440/220    0.002    0.000    0.057    0.000 eval.py:45(__getitem__)
#       220    0.000    0.000    0.000    0.000 eval.py:451(name)
#      2620    0.006    0.000    0.009    0.000 eval.py:464(__hash__)
#       220    0.002    0.000    0.074    0.000 eval.py:545(_eval)
#       220    0.001    0.000    0.075    0.000 eval.py:563(eval)
#        20    0.000    0.000    0.000    0.000 expressions.py:186(_has_bool_dtype)
#        20    0.000    0.000    0.000    0.000 expressions.py:195(_bool_arith_check)
#        20    0.000    0.000    0.003    0.000 expressions.py:217(evaluate)
#        20    0.000    0.000    0.001    0.000 expressions.py:61(_evaluate_standard)
#        20    0.000    0.000    0.002    0.000 expressions.py:71(_can_use_numexpr)
#        20    0.000    0.000    0.003    0.000 expressions.py:97(_evaluate_numexpr)
#        40    0.001    0.000    0.010    0.000 format.py:1027(<listcomp>)
#        80    0.000    0.000    0.001    0.000 format.py:1033(has_index_names)
#        40    0.000    0.000    0.001    0.000 format.py:1037(has_column_names)
#        80    0.000    0.000    0.001    0.000 format.py:1041(show_row_idx_names)
#        40    0.000    0.000    0.001    0.000 format.py:1045(show_col_idx_names)
#        40    0.001    0.000    0.032    0.001 format.py:1049(_get_formatted_index)
#        40    0.000    0.000    0.000    0.000 format.py:1052(<dictcomp>)
#        40    0.000    0.000    0.004    0.000 format.py:1068(<listcomp>)
#       420    0.011    0.000    0.192    0.000 format.py:1103(format_array)
#       420    0.002    0.000    0.002    0.000 format.py:1183(__init__)
#       420    0.003    0.000    0.092    0.000 format.py:1209(get_result)
#        20    0.000    0.000    0.000    0.000 format.py:1287(__init__)
#        20    0.000    0.000    0.000    0.000 format.py:1299(_value_formatter)
#        20    0.000    0.000    0.001    0.000 format.py:1317(base_formatter)
#        20    0.001    0.000    0.011    0.001 format.py:1347(get_result_as_array)
#        20    0.001    0.000    0.007    0.000 format.py:1361(format_values_with)
#        20    0.000    0.000    0.001    0.000 format.py:1379(<listcomp>)
#        40    0.000    0.000    0.000    0.000 format.py:1414(<genexpr>)
#        20    0.000    0.000    0.011    0.001 format.py:1435(_format_strings)
#       400    0.002    0.000    0.008    0.000 format.py:1444(_format_strings)
#       400    0.002    0.000    0.002    0.000 format.py:1445(<lambda>)
#       400    0.003    0.000    0.006    0.000 format.py:1446(<listcomp>)
#       800    0.013    0.000    0.102    0.000 format.py:1723(_make_fixed_width)
#      1600    0.003    0.000    0.006    0.000 format.py:1736(<genexpr>)
#       800    0.002    0.000    0.005    0.000 format.py:1745(just)
#       800    0.002    0.000    0.008    0.000 format.py:1751(<listcomp>)
#        20    0.000    0.000    0.001    0.000 format.py:1769(_trim_zeros_float)
#        30    0.000    0.000    0.000    0.000 format.py:1777(_is_number)
#        25    0.000    0.000    0.001    0.000 format.py:1780(_cond)
#        25    0.000    0.000    0.000    0.000 format.py:1781(<listcomp>)
#        25    0.000    0.000    0.000    0.000 format.py:1782(<listcomp>)
#        50    0.000    0.000    0.000    0.000 format.py:1787(<genexpr>)
#        10    0.000    0.000    0.000    0.000 format.py:1788(<genexpr>)
#         5    0.000    0.000    0.000    0.000 format.py:1792(<listcomp>)
#        20    0.000    0.000    0.000    0.000 format.py:1795(<listcomp>)
#       120    0.001    0.000    0.001    0.000 format.py:1798(_has_names)
#        20    0.000    0.000    0.003    0.000 format.py:231(__init__)
#        20    0.000    0.000    0.001    0.000 format.py:263(_chk_truncate)
#        20    0.000    0.000    0.004    0.000 format.py:292(_get_footer)
#        20    0.000    0.000    0.010    0.001 format.py:331(_get_formatted_index)
#        20    0.000    0.000    0.019    0.001 format.py:342(_get_formatted_values)
#        20    0.000    0.000    0.037    0.002 format.py:350(to_string)
#       460    0.001    0.000    0.017    0.000 format.py:390(__init__)
#      3020    0.007    0.000    0.010    0.000 format.py:393(len)
#      1620    0.005    0.000    0.018    0.000 format.py:396(justify)
#       100    0.001    0.000    0.022    0.000 format.py:399(adjoin)
#       460    0.002    0.000    0.036    0.000 format.py:442(_get_adjustment)
#        20    0.000    0.000    0.000    0.000 format.py:457(should_show_dimensions)
#       720    0.006    0.000    0.020    0.000 format.py:463(_get_formatter)
#        40    0.000    0.000    0.001    0.000 format.py:475(get_buffer)
#        20    0.001    0.000    1.543    0.077 format.py:511(get_result)
#        20    0.000    0.000    0.006    0.000 format.py:541(__init__)
#        40    0.002    0.000    0.098    0.002 format.py:633(_chk_truncate)
#        40    0.013    0.000    0.530    0.013 format.py:726(_to_str_columns)
#        40    0.000    0.000    0.000    0.000 format.py:732(<dictcomp>)
#       680    0.001    0.000    0.003    0.000 format.py:768(<genexpr>)
#       680    0.001    0.000    0.002    0.000 format.py:775(<genexpr>)
#        20    0.005    0.000    1.541    0.077 format.py:817(write_result)
#        20    0.005    0.000    0.610    0.030 format.py:849(<listcomp>)
#        20    0.000    0.000    1.543    0.077 format.py:916(to_string)
#       340    0.007    0.000    0.336    0.001 format.py:951(_format_col)
#        40    0.002    0.000    0.101    0.003 format.py:992(_get_formatted_column_labels)
#       160    0.001    0.000    0.002    0.000 frame.py:1099(__len__)
#        20    0.001    0.000    1.955    0.098 frame.py:2687(transpose)
#        20    0.000    0.000    1.955    0.098 frame.py:2809(T)
#       360    0.004    0.000    0.098    0.000 frame.py:2816(_ixs)
#       200    0.001    0.000    0.035    0.000 frame.py:2854(_get_column_array)
#       400    0.002    0.000    0.038    0.000 frame.py:2861(_iter_column_arrays)
#       240    0.006    0.000    0.143    0.001 frame.py:2869(__getitem__)
#       560    0.005    0.000    0.037    0.000 frame.py:3184(_box_col_values)
#       920    0.001    0.000    0.001    0.000 frame.py:421(_constructor)
#      1180    0.032    0.000    2.783    0.002 frame.py:441(__init__)
#       480    0.001    0.000    0.001    0.000 frame.py:568(axes)
#       880    0.004    0.000    0.015    0.000 frame.py:585(shape)
#       200    0.001    0.000    0.153    0.001 frame.py:5853(_combine_frame)
#       200    0.003    0.000    0.022    0.000 frame.py:5873(_construct_result)
#       220    0.002    0.000    0.013    0.000 frame.py:607(_is_homogeneous_type)
#        20    0.000    0.000    0.001    0.000 frame.py:717(_info_repr)
#        20    0.001    0.000    1.565    0.078 frame.py:726(__repr__)
#        20    0.001    0.000    1.555    0.078 frame.py:802(to_string)
#       200    0.009    0.000    0.272    0.001 frame.py:8531(_reduce)
#       200    0.001    0.000    0.040    0.000 frame.py:8546(<listcomp>)
#       200    0.002    0.000    0.072    0.000 frame.py:8571(func)
#       200    0.000    0.000    0.000    0.000 frame.py:8883(_get_agg_axis)
#       220    0.000    0.000    0.000    0.000 fromnumeric.py:2245(_any_dispatcher)
#       220    0.002    0.000    0.289    0.001 fromnumeric.py:2249(any)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:2333(_all_dispatcher)
#        20    0.000    0.000    0.001    0.000 fromnumeric.py:2337(all)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:2876(_prod_dispatcher)
#        20    0.000    0.000    0.001    0.000 fromnumeric.py:2881(prod)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:3071(_ndim_dispatcher)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:3075(ndim)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:433(_repeat_dispatcher)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:437(repeat)
#        40    0.000    0.000    0.001    0.000 fromnumeric.py:52(_wrapfunc)
#       260    0.004    0.000    0.289    0.001 fromnumeric.py:70(_wrapreduction)
#       260    0.001    0.000    0.001    0.000 fromnumeric.py:71(<dictcomp>)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:995(_argsort_dispatcher)
#        20    0.000    0.000    0.001    0.000 fromnumeric.py:999(argsort)
#        20    0.000    0.000    0.000    0.000 frozen.py:66(__getitem__)
#       500    0.002    0.000    0.007    0.000 function.py:48(__call__)
#       100    0.000    0.000    0.000    0.000 function_base.py:4232(_delete_dispatcher)
#       100    0.003    0.000    0.006    0.000 function_base.py:4236(delete)
#    153340    0.376    0.000    0.559    0.000 generic.py:10(_check)
#       260    0.003    0.000    0.074    0.000 generic.py:11451(stat_func)
#       200    0.004    0.000    0.282    0.001 generic.py:11562(logical_func)
#       400    0.002    0.000    0.019    0.000 generic.py:1193(_indexed_same)
#      1000    0.004    0.000    0.015    0.000 generic.py:1195(<genexpr>)
#        20    0.000    0.000    0.009    0.000 generic.py:1319(__invert__)
#        40    0.000    0.000    0.001    0.000 generic.py:1673(__iter__)
#       620    0.003    0.000    0.051    0.000 generic.py:1780(__array__)
#       200    0.004    0.000    0.127    0.001 generic.py:1783(__array_wrap__)
#      3200    0.013    0.000    0.013    0.000 generic.py:195(__init__)
#      1220    0.002    0.000    0.002    0.000 generic.py:232(attrs)
#        80    0.000    0.000    0.002    0.000 generic.py:249(_validate_dtype)
#       200    0.000    0.000    0.000    0.000 generic.py:294(_data)
#       560    0.002    0.000    0.004    0.000 generic.py:3180(_set_as_cached)
# ...
#        20    0.000    0.000    0.000    0.000 inspect.py:1507(currentframe)
#       260    0.001    0.000    0.001    0.000 inspect.py:72(isclass)
#        20    0.000    0.000    0.000    0.000 interactiveshell.py:518(get_ipython)
#         5    0.000    0.000    0.000    0.000 iostream.py:195(schedule)
#         4    0.000    0.000    0.000    0.000 iostream.py:307(_is_master_process)
#         4    0.000    0.000    0.000    0.000 iostream.py:320(_schedule_flush)
#         4    0.000    0.000    0.001    0.000 iostream.py:382(write)
#         5    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#        20    0.000    0.000    0.001    0.000 linear_model.py:339(predict)
#       200    0.002    0.000    0.033    0.000 managers.py:1008(iget_values)
#       120    0.002    0.000    0.083    0.001 managers.py:1247(reindex_indexer)
#       360    0.007    0.000    0.095    0.000 managers.py:1309(_slice_take_blocks_ax0)
#       980    0.014    0.000    0.129    0.000 managers.py:132(__init__)
#       980    0.006    0.000    0.015    0.000 managers.py:138(<listcomp>)
#        20    0.001    0.000    0.025    0.001 managers.py:1436(take)
#      2020    0.012    0.000    0.017    0.000 managers.py:1541(__init__)
#        40    0.000    0.000    0.001    0.000 managers.py:156(from_blocks)
#       360    0.002    0.000    0.006    0.000 managers.py:1562(from_blocks)
#      1100    0.009    0.000    0.278    0.000 managers.py:1573(from_array)
#      5020    0.006    0.000    0.006    0.000 managers.py:1584(_block)
#      2360    0.009    0.000    0.015    0.000 managers.py:1611(dtype)
#        20    0.000    0.000    0.000    0.000 managers.py:1618(external_values)
#      1940    0.008    0.000    0.013    0.000 managers.py:1622(internal_values)
#       840    0.002    0.000    0.041    0.000 managers.py:163(blknos)
#       100    0.000    0.000    0.000    0.000 managers.py:1630(is_consolidated)
#       100    0.000    0.000    0.000    0.000 managers.py:1636(_consolidate_inplace)
#       460    0.007    0.000    0.471    0.001 managers.py:1660(create_block_manager_from_blocks)
#       220    0.005    0.000    0.204    0.001 managers.py:1684(create_block_manager_from_arrays)
#       660    0.001    0.000    0.002    0.000 managers.py:1689(<genexpr>)
#       220    0.020    0.000    0.171    0.001 managers.py:1724(form_blocks)
#       780    0.001    0.000    0.001    0.000 managers.py:179(blklocs)
#        20    0.000    0.000    0.007    0.000 managers.py:1821(_simple_blockify)
#       200    0.004    0.000    0.077    0.000 managers.py:1836(_multi_blockify)
#       200    0.001    0.000    0.002    0.000 managers.py:1839(<lambda>)
#       220    0.006    0.000    0.019    0.000 managers.py:1852(_stack_arrays)
#       220    0.001    0.000    0.005    0.000 managers.py:1855(_asarray_compat)
#       220    0.001    0.000    0.007    0.000 managers.py:1861(_shape_compat)
#        20    0.000    0.000    0.006    0.000 managers.py:1879(_interleaved_dtype)
#        20    0.000    0.000    0.000    0.000 managers.py:1895(<listcomp>)
#        20    0.007    0.000    0.242    0.012 managers.py:1898(_consolidate)
#      8760    0.022    0.000    0.163    0.000 managers.py:1903(<lambda>)
#        40    0.001    0.000    0.065    0.002 managers.py:1915(_merge_blocks)
#        20    0.006    0.000    0.011    0.001 managers.py:1930(<listcomp>)
#        20    0.001    0.000    0.001    0.000 managers.py:1931(<listcomp>)
#       360    0.002    0.000    0.004    0.000 managers.py:2024(_preprocess_slice_or_indexer)
#      1680    0.012    0.000    0.042    0.000 managers.py:212(shape)
#      4940    0.010    0.000    0.030    0.000 managers.py:214(<genexpr>)
#      6280    0.014    0.000    0.020    0.000 managers.py:216(ndim)
#       400    0.002    0.000    0.007    0.000 managers.py:220(set_axis)
#      1140    0.003    0.000    0.004    0.000 managers.py:233(_is_single_block)
#       280    0.013    0.000    0.042    0.000 managers.py:238(_rebuild_blknos_and_blklocs)
#      1400    0.002    0.000    0.002    0.000 managers.py:259(items)
#        60    0.001    0.000    0.013    0.000 managers.py:263(get_dtypes)
#        60    0.000    0.000    0.000    0.000 managers.py:264(<listcomp>)
#       700    0.003    0.000    0.009    0.000 managers.py:309(__len__)
#       700    0.015    0.000    0.083    0.000 managers.py:324(_verify_integrity)
#      5760    0.019    0.000    0.031    0.000 managers.py:326(<genexpr>)
#       200    0.002    0.000    0.135    0.001 managers.py:363(operate_blockwise)
#       280    0.006    0.000    0.067    0.000 managers.py:369(apply)
#       280    0.000    0.000    0.000    0.000 managers.py:388(<dictcomp>)
#       260    0.002    0.000    0.061    0.000 managers.py:601(astype)
#      1840    0.004    0.000    0.028    0.000 managers.py:684(is_consolidated)
#       920    0.007    0.000    0.024    0.000 managers.py:692(_consolidate_check)
#       920    0.009    0.000    0.015    0.000 managers.py:693(<listcomp>)
#       220    0.001    0.000    0.005    0.000 managers.py:697(is_mixed_type)
#       420    0.001    0.000    0.004    0.000 managers.py:707(any_extension_types)
#       840    0.001    0.000    0.001    0.000 managers.py:710(<genexpr>)
#        40    0.000    0.000    0.000    0.000 managers.py:712(is_view)
#        40    0.001    0.000    0.005    0.000 managers.py:766(get_slice)
#       840    0.011    0.000    0.034    0.000 managers.py:815(as_array)
#        20    0.008    0.000    0.028    0.001 managers.py:935(fast_xs)
#      1000    0.003    0.000    0.005    0.000 managers.py:970(consolidate)
#       940    0.003    0.000    0.274    0.000 managers.py:986(_consolidate_inplace)
#       560    0.009    0.000    0.039    0.000 managers.py:993(iget)
#       200    0.005    0.000    0.204    0.001 methods.py:95(f)
#        20    0.000    0.000    0.000    0.000 missing.py:119(is_categorical_NA)
#       200    0.013    0.000    0.789    0.004 missing.py:129(is_numerical_NA)
#       360    0.002    0.000    0.022    0.000 missing.py:130(_isna)
#        20    0.000    0.000    0.000    0.000 missing.py:136(dispatch_fill_zeros)
#        20    0.000    0.000    0.247    0.012 missing.py:141(handle_NA)
#        20    0.002    0.000    0.247    0.012 missing.py:175(_handle_NA_drop)
#        20    0.004    0.000    0.017    0.001 missing.py:181(<listcomp>)
#        80    0.001    0.000    0.018    0.000 missing.py:193(_isna_ndarraylike)
#        60    0.002    0.000    0.004    0.000 missing.py:235(_isna_string_dtype)
#        20    0.000    0.000    0.000    0.000 missing.py:255(notna)
#       280    0.002    0.000    0.022    0.000 missing.py:358(array_equivalent)
#       360    0.001    0.000    0.023    0.000 missing.py:47(isna)
#       300    0.001    0.000    0.001    0.000 missing.py:665(clean_reindex_fill_method)
#       300    0.001    0.000    0.001    0.000 missing.py:75(clean_fill_method)
#        40    0.000    0.000    0.000    0.000 missing.py:88(__init__)
#        20    0.002    0.000    1.898    0.095 model.py:950(predict)
#       680    0.001    0.000    0.001    0.000 multiarray.py:1043(copyto)
#        60    0.000    0.000    0.000    0.000 multiarray.py:143(concatenate)
#        40    0.000    0.000    0.000    0.000 multiarray.py:468(can_cast)
#        20    0.000    0.000    0.000    0.000 multiarray.py:706(dot)
#       260    0.001    0.000    0.026    0.000 nanops.py:136(_bn_ok_dtype)
#       260    0.006    0.000    0.013    0.000 nanops.py:155(_has_infs)
#       200    0.000    0.000    0.000    0.000 nanops.py:168(_get_fill_value)
#       200    0.001    0.000    0.008    0.000 nanops.py:193(_maybe_get_mask)
#       200    0.004    0.000    0.062    0.000 nanops.py:237(_get_values)
#       200    0.001    0.000    0.016    0.000 nanops.py:322(_na_ok_dtype)
#       200    0.001    0.000    0.067    0.000 nanops.py:396(nanany)
#       260    0.004    0.000    0.048    0.000 nanops.py:97(f)
#       140    0.001    0.000    0.004    0.000 numeric.py:105(_shallow_copy)
#       100    0.001    0.000    0.002    0.000 numeric.py:144(ones)
#      1600    0.002    0.000    0.002    0.000 numeric.py:150(is_all_dates)
#        60    0.000    0.000    0.000    0.000 numeric.py:2313(_array_equal_dispatcher)
#        60    0.001    0.000    0.003    0.000 numeric.py:2317(array_equal)
#       820    0.001    0.000    0.001    0.000 numeric.py:237(inferred_type)
#       580    0.005    0.000    0.015    0.000 numeric.py:268(full)
#       100    0.002    0.000    0.007    0.000 numeric.py:50(__new__)
#       380    0.001    0.000    0.001    0.000 numeric.py:81(_validate_dtype)
#      2080    0.007    0.000    0.010    0.000 numerictypes.py:286(issubclass_)
#      1040    0.007    0.000    0.018    0.000 numerictypes.py:360(issubdtype)
#       700    0.005    0.000    0.008    0.000 numpy_.py:162(__init__)
#       280    0.001    0.000    0.002    0.000 numpy_.py:210(__array__)
#       420    0.002    0.000    0.003    0.000 numpy_.py:414(to_numpy)
#       700    0.001    0.000    0.001    0.000 numpy_.py:50(__init__)
#       200    0.009    0.000    0.133    0.001 ops.py:12(operate_blockwise)
#       200    0.002    0.000    0.010    0.000 ops.py:64(_reset_block_mgr_locs)
#       200    0.002    0.000    0.002    0.000 ops.py:76(_get_same_shape_values)
#       160    0.001    0.000    0.002    0.000 os.py:676(__getitem__)
#       160    0.001    0.000    0.001    0.000 os.py:754(encode)
#       360    0.005    0.000    0.024    0.000 printing.py:166(pprint_thing)
#       360    0.003    0.000    0.005    0.000 printing.py:197(as_escaped_string)
#       100    0.006    0.000    0.021    0.000 printing.py:29(adjoin)
#       100    0.001    0.000    0.005    0.000 printing.py:50(<listcomp>)
#      1620    0.005    0.000    0.013    0.000 printing.py:64(justify)
#       580    0.002    0.000    0.003    0.000 printing.py:69(<listcomp>)
#      1040    0.003    0.000    0.004    0.000 printing.py:73(<listcomp>)
#         1    0.000    0.000    5.676    5.676 profile:0(print(predict(20));print('=' * 100))
#         0    0.000             0.000          profile:0(profiler)
#        20    0.000    0.000    0.001    0.000 random.py:174(randrange)
#        20    0.000    0.000    0.001    0.000 random.py:218(randint)
#        20    0.000    0.000    0.000    0.000 random.py:224(_randbelow)
#       280    0.003    0.000    0.009    0.000 range.py:134(_simple_new)
#        60    0.000    0.000    0.000    0.000 range.py:153(_data)
#        20    0.000    0.000    0.000    0.000 range.py:214(start)
#        20    0.000    0.000    0.000    0.000 range.py:237(stop)
#        20    0.000    0.000    0.000    0.000 range.py:260(step)
#        60    0.000    0.000    0.000    0.000 range.py:320(dtype)
#        60    0.000    0.000    0.000    0.000 range.py:324(is_unique)
#        20    0.000    0.000    0.000    0.000 range.py:349(get_loc)
#        40    0.002    0.000    0.006    0.000 range.py:361(get_indexer)
#        20    0.000    0.000    0.000    0.000 range.py:393(_shallow_copy)
#        40    0.000    0.000    0.004    0.000 range.py:452(equals)
#      1700    0.004    0.000    0.006    0.000 range.py:687(__len__)
#        40    0.000    0.000    0.000    0.000 range.py:697(__getitem__)
#       280    0.005    0.000    0.025    0.000 range.py:86(__new__)
#       200    0.001    0.000    0.003    0.000 roperator.py:55(ror_)
#        20    0.001    0.000    0.046    0.002 series.py:1310(__repr__)
#        20    0.000    0.000    0.040    0.002 series.py:1340(to_string)
#      2020    0.051    0.000    0.810    0.000 series.py:201(__init__)
#       220    0.003    0.000    0.121    0.001 series.py:2741(_construct_result)
#       860    0.001    0.000    0.001    0.000 series.py:381(_constructor)
#      1660    0.007    0.000    0.010    0.000 series.py:398(_set_axis)
#       240    0.011    0.000    0.310    0.001 series.py:4084(apply)
#       260    0.005    0.000    0.070    0.000 series.py:4224(_reduce)
#       100    0.000    0.000    0.000    0.000 series.py:4262(_needs_reindex_multi)
#      2360    0.007    0.000    0.022    0.000 series.py:427(dtype)
#       100    0.001    0.000    0.121    0.001 series.py:4404(reindex)
#       100    0.001    0.000    0.190    0.002 series.py:4414(drop)
#      4640    0.012    0.000    0.018    0.000 series.py:442(name)
#      3160    0.010    0.000    0.021    0.000 series.py:492(name)
#        20    0.000    0.000    0.000    0.000 series.py:498(values)
#      1940    0.005    0.000    0.018    0.000 series.py:540(_values)
#       700    0.003    0.000    0.014    0.000 series.py:574(array)
#       680    0.002    0.000    0.012    0.000 series.py:595(__len__)
#        20    0.001    0.000    0.016    0.001 series.py:675(__array_ufunc__)
#        20    0.000    0.000    0.000    0.000 series.py:705(<listcomp>)
#        60    0.000    0.000    0.000    0.000 series.py:706(<genexpr>)
#        20    0.000    0.000    0.000    0.000 series.py:708(<listcomp>)
#        60    0.000    0.000    0.002    0.000 series.py:725(<genexpr>)
#        20    0.000    0.000    0.011    0.001 series.py:730(construct_return)
#       280    0.001    0.000    0.011    0.000 series.py:750(__array__)
#       100    0.001    0.000    0.011    0.000 series.py:868(__getitem__)
#       100    0.001    0.000    0.008    0.000 series.py:973(_get_value)
#        60    0.000    0.000    0.000    0.000 shape_base.py:20(_atleast_1d_dispatcher)
#        20    0.000    0.000    0.000    0.000 shape_base.py:208(_arrays_for_stack_dispatcher)
#        20    0.000    0.000    0.000    0.000 shape_base.py:219(_vhstack_dispatcher)
#        20    0.000    0.000    0.037    0.002 shape_base.py:223(vstack)
#        60    0.000    0.000    0.001    0.000 shape_base.py:24(atleast_1d)
#        40    0.000    0.000    0.000    0.000 shape_base.py:78(_atleast_2d_dispatcher)
#        40    0.013    0.000    0.035    0.001 shape_base.py:82(atleast_2d)
#        80    0.002    0.000    0.005    0.000 shutil.py:1073(get_terminal_size)
#        80    0.000    0.000    0.000    0.000 six.py:585(itervalues)
#       240    0.001    0.000    0.001    0.000 six.py:588(iteritems)
#         5    0.000    0.000    0.000    0.000 socket.py:438(send)
#        20    0.000    0.000    0.010    0.001 strings.py:121(_na_map)
#        20    0.000    0.000    0.027    0.001 strings.py:1993(wrapper)
#        20    0.000    0.000    0.027    0.001 strings.py:2017(wrapper)
#        20    0.001    0.000    0.010    0.000 strings.py:203(_map_object)
#        20    0.000    0.000    0.004    0.000 strings.py:2099(__init__)
#        20    0.000    0.000    0.002    0.000 strings.py:2110(_validate)
#        20    0.001    0.000    0.016    0.001 strings.py:2179(_wrap_result)
#         5    0.000    0.000    0.000    0.000 threading.py:1050(_wait_for_tstate_lock)
#         5    0.000    0.000    0.000    0.000 threading.py:1092(is_alive)
#         5    0.000    0.000    0.000    0.000 threading.py:507(is_set)
#       360    0.002    0.000    0.010    0.000 typing.py:248(inner)
#       720    0.002    0.000    0.003    0.000 typing.py:322(__hash__)
#  1080/360    0.004    0.000    0.007    0.000 typing.py:669(__hash__)
#        20    0.000    0.000    0.000    0.000 typing.py:898(cast)
#       260    0.002    0.000    0.505    0.002 util.py:159(atleast_2d_column_default)
#        20    0.000    0.000    0.000    0.000 util.py:556(safe_scalar_isnan)
#        20    0.000    0.000    0.001    0.000 util.py:583(iterable)
#       360    0.001    0.000    0.011    0.000 util.py:669(safe_is_pandas_categorical_dtype)
#        20    0.000    0.000    0.001    0.000 util.py:675(safe_is_pandas_categorical)
#       340    0.002    0.000    0.019    0.000 util.py:707(safe_issubdtype)
#        20    0.000    0.000    0.000    0.000 warnings.py:165(simplefilter)
#        20    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#        60    0.000    0.000    0.000    0.000 warnings.py:449(__init__)
#        60    0.000    0.000    0.001    0.000 warnings.py:470(__enter__)
#        60    0.000    0.000    0.000    0.000 warnings.py:489(__exit__)
#     40/20    0.000    0.000    0.001    0.000 wrapper.py:22(__getattribute__)
#        80    0.000    0.000    0.000    0.000 wrapper.py:23(<lambda>)

# %%
# %timeit predict(10)
# Out:
# 1 loop, best of 5: 220 ms per loop

# %%
cProfile.run('predict(10)')
# Out:
#          627446 function calls (621006 primitive calls) in 0.439 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       110    0.000    0.000    0.036    0.000 <__array_function__ internals>:2(any)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(argsort)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(array_equal)
#        30    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_1d)
#        20    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(atleast_2d)
#        20    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(can_cast)
#        20    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(concatenate)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(dot)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(ndim)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(prod)
#        10    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(repeat)
#        10    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(vstack)
#      3990    0.004    0.000    0.007    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#         1    0.001    0.001    0.439    0.439 <ipython-input-126-a1135e583ebd>:1(predict)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#        90    0.000    0.000    0.000    0.000 __init__.py:111(_maybe_match_name)
#       100    0.001    0.000    0.018    0.000 __init__.py:243(dispatch_to_series)
#       100    0.000    0.000    0.000    0.000 __init__.py:307(_align_method_SERIES)
#        10    0.000    0.000    0.004    0.000 __init__.py:359(wrapper)
#       100    0.000    0.000    0.019    0.000 __init__.py:386(wrapper)
#       100    0.001    0.000    0.013    0.000 __init__.py:433(_align_method_FRAME)
#       100    0.000    0.000    0.000    0.000 __init__.py:524(_should_reindex_frame_op)
#       100    0.001    0.000    0.034    0.000 __init__.py:634(f)
#       110    0.000    0.000    0.001    0.000 __init__.py:88(get_op_result_name)
# 2180/1600    0.001    0.000    0.010    0.000 _asarray.py:14(asarray)
#      2410    0.008    0.000    0.018    0.000 _asarray.py:221(require)
#      2410    0.002    0.000    0.003    0.000 _asarray.py:298(<setcomp>)
#      2240    0.000    0.000    0.001    0.000 _asarray.py:86(asanyarray)
#        20    0.000    0.000    0.000    0.000 _dtype.py:178(_datetime_metadata_str)
#      4920    0.001    0.000    0.001    0.000 _dtype.py:24(_kind_name)
#      4920    0.002    0.000    0.002    0.000 _dtype.py:307(_name_includes_bit_suffix)
#      4920    0.007    0.000    0.011    0.000 _dtype.py:321(_name_get)
#        10    0.000    0.000    0.000    0.000 _methods.py:37(_amax)
#        10    0.000    0.000    0.000    0.000 _methods.py:45(_sum)
#       260    0.000    0.000    0.002    0.000 _methods.py:53(_any)
#        20    0.000    0.000    0.000    0.000 _methods.py:56(_all)
#        10    0.000    0.000    0.000    0.000 _mixins.py:89(reshape)
#        60    0.000    0.000    0.000    0.000 _ufunc_config.py:132(geterr)
#        60    0.000    0.000    0.001    0.000 _ufunc_config.py:32(seterr)
#        30    0.000    0.000    0.000    0.000 _ufunc_config.py:429(__init__)
#        30    0.000    0.000    0.000    0.000 _ufunc_config.py:433(__enter__)
#        30    0.000    0.000    0.000    0.000 _ufunc_config.py:438(__exit__)
#       100    0.000    0.000    0.000    0.000 _validators.py:112(_check_for_invalid_keys)
#       100    0.000    0.000    0.001    0.000 _validators.py:125(validate_kwargs)
#       100    0.000    0.000    0.000    0.000 _validators.py:33(_check_for_default_values)
#      3510    0.001    0.000    0.003    0.000 abc.py:137(__instancecheck__)
#        10    0.000    0.000    0.000    0.000 abc.py:141(__subclasscheck__)
#        40    0.000    0.000    0.001    0.000 algorithms.py:1511(_get_take_nd_function)
#        40    0.001    0.000    0.003    0.000 algorithms.py:1640(take_nd)
#       110    0.000    0.000    0.000    0.000 api.py:161(union_indexes)
#        10    0.000    0.000    0.001    0.000 array_ops.py:119(na_arithmetic_op)
#        10    0.000    0.000    0.002    0.000 array_ops.py:195(comparison_op)
#       200    0.000    0.000    0.002    0.000 array_ops.py:256(na_logical_op)
#       200    0.001    0.000    0.009    0.000 array_ops.py:297(logical_op)
#       400    0.001    0.000    0.003    0.000 array_ops.py:315(fill_bool)
#       100    0.000    0.000    0.000    0.000 array_ops.py:362(get_array_op)
#       210    0.000    0.000    0.000    0.000 array_ops.py:404(maybe_upcast_datetimelike_array)
#        30    0.000    0.000    0.000    0.000 base.py:1032(__iter__)
#        40    0.000    0.000    0.000    0.000 base.py:1175(name)
#       120    0.000    0.000    0.000    0.000 base.py:1378(nlevels)
#        10    0.000    0.000    0.000    0.000 base.py:1646(is_unique)
#        20    0.000    0.000    0.000    0.000 base.py:1685(is_boolean)
#       110    0.000    0.000    0.000    0.000 base.py:1755(is_floating)
#       120    0.000    0.000    0.001    0.000 base.py:1841(is_object)
#        30    0.000    0.000    0.001    0.000 base.py:2000(inferred_type)
#     14350    0.013    0.000    0.046    0.000 base.py:256(is_dtype)
#       110    0.000    0.000    0.001    0.000 base.py:2854(get_loc)
#   420/150    0.007    0.000    0.037    0.000 base.py:293(__new__)
#        20    0.000    0.000    0.004    0.000 base.py:2960(get_indexer)
#        10    0.000    0.000    0.000    0.000 base.py:3197(_convert_listlike_indexer)
#        10    0.000    0.000    0.000    0.000 base.py:3219(_convert_arr_indexer)
#        10    0.000    0.000    0.000    0.000 base.py:3250(_convert_list_indexer)
#        10    0.000    0.000    0.003    0.000 base.py:3294(reindex)
#       230    0.000    0.000    0.000    0.000 base.py:3873(_values)
#       150    0.000    0.000    0.000    0.000 base.py:3899(_get_engine_target)
#       230    0.001    0.000    0.002    0.000 base.py:4039(__contains__)
#       230    0.001    0.000    0.002    0.000 base.py:4086(__getitem__)
#       120    0.000    0.000    0.003    0.000 base.py:4123(_can_hold_identifiers_and_holds_name)
#      5940    0.005    0.000    0.008    0.000 base.py:413(find)
#       830    0.001    0.000    0.002    0.000 base.py:4199(equals)
#       220    0.000    0.000    0.000    0.000 base.py:424(<genexpr>)
#       170    0.000    0.000    0.001    0.000 base.py:463(_simple_new)
#        10    0.000    0.000    0.004    0.000 base.py:4703(get_indexer_for)
#        20    0.000    0.000    0.000    0.000 base.py:4720(_maybe_promote)
#       110    0.000    0.000    0.001    0.000 base.py:4979(_maybe_cast_indexer)
#        20    0.000    0.000    0.000    0.000 base.py:498(_shallow_copy)
#       830    0.001    0.000    0.001    0.000 base.py:520(is_)
#       170    0.000    0.000    0.000    0.000 base.py:544(_reset_identity)
#       130    0.000    0.000    0.001    0.000 base.py:554(_engine)
#      2200    0.001    0.000    0.010    0.000 base.py:5562(ensure_index)
#       130    0.000    0.000    0.000    0.000 base.py:561(<lambda>)
#        10    0.000    0.000    0.000    0.000 base.py:5626(ensure_has_len)
#       690    0.001    0.000    0.002    0.000 base.py:5659(maybe_extract_name)
#      4530    0.002    0.000    0.002    0.000 base.py:567(__len__)
#       150    0.000    0.000    0.002    0.000 base.py:5675(_maybe_cast_with_dtype)
#       150    0.001    0.000    0.004    0.000 base.py:5729(_maybe_cast_data_without_dtype)
#        10    0.000    0.000    0.000    0.000 base.py:5800(_try_convert_to_int_array)
#       150    0.000    0.000    0.000    0.000 base.py:590(dtype)
#        10    0.000    0.000    0.000    0.000 base.py:626(shape)
#       140    0.000    0.000    0.000    0.000 base.py:637(ndim)
#        10    0.000    0.000    0.000    0.000 base.py:669(size)
#        10    0.000    0.000    0.000    0.000 base.py:701(take)
#        10    0.000    0.000    0.000    0.000 base.py:723(_assert_take_fillable)
#       100    0.000    0.000    0.000    0.000 blocks.py:111(_simple_new)
#        10    0.000    0.000    0.001    0.000 blocks.py:1238(take_nd)
#      3020    0.007    0.000    0.040    0.000 blocks.py:124(__init__)
#      3020    0.001    0.000    0.001    0.000 blocks.py:135(_check_ndim)
#      4380    0.007    0.000    0.016    0.000 blocks.py:176(_consolidate_key)
#        10    0.000    0.000    0.000    0.000 blocks.py:2008(_holder)
#       420    0.000    0.000    0.000    0.000 blocks.py:201(internal_values)
#        10    0.000    0.000    0.000    0.000 blocks.py:2029(array_values)
#        10    0.000    0.000    0.001    0.000 blocks.py:2032(iget)
#        10    0.000    0.000    0.000    0.000 blocks.py:2048(__init__)
#        10    0.000    0.000    0.000    0.000 blocks.py:2056(_maybe_coerce_values)
#       350    0.000    0.000    0.002    0.000 blocks.py:207(array_values)
#       430    0.000    0.000    0.002    0.000 blocks.py:213(get_values)
#        10    0.000    0.000    0.000    0.000 blocks.py:229(fill_value)
#      8430    0.002    0.000    0.002    0.000 blocks.py:233(mgr_locs)
#      3120    0.007    0.000    0.026    0.000 blocks.py:237(mgr_locs)
#      2230    0.003    0.000    0.035    0.000 blocks.py:2396(__init__)
#       110    0.000    0.000    0.004    0.000 blocks.py:244(make_block)
#       120    0.000    0.000    0.001    0.000 blocks.py:256(make_block_same_class)
#      3010    0.013    0.000    0.090    0.000 blocks.py:2677(get_block_type)
#      2900    0.006    0.000    0.137    0.000 blocks.py:2723(make_block)
#        40    0.000    0.000    0.000    0.000 blocks.py:2750(_extend_blocks)
#       100    0.000    0.000    0.000    0.000 blocks.py:287(_slice)
#       100    0.000    0.000    0.001    0.000 blocks.py:292(getitem_block)
#      2530    0.001    0.000    0.001    0.000 blocks.py:311(shape)
#      8080    0.002    0.000    0.002    0.000 blocks.py:315(dtype)
#      2390    0.001    0.000    0.001    0.000 blocks.py:319(iget)
#        10    0.000    0.000    0.001    0.000 blocks.py:340(apply)
#       110    0.000    0.000    0.005    0.000 blocks.py:350(_split_op_result)
#        10    0.000    0.000    0.001    0.000 blocks.py:514(astype)
#       240    0.000    0.000    0.000    0.000 build.py:207(_column_combinations)
#       120    0.000    0.000    0.000    0.000 build.py:209(<listcomp>)
#       120    0.000    0.000    0.000    0.000 build.py:223(_subterm_column_combinations)
#       120    0.002    0.000    0.003    0.000 build.py:259(_build_subterm)
#        10    0.000    0.000    0.000    0.000 build.py:347(_factors_memorize)
#       100    0.000    0.000    0.000    0.000 build.py:42(_max_allowed_dim)
#        10    0.000    0.000    0.000    0.000 build.py:437(_examine_factor_types)
#        10    0.000    0.000    0.000    0.000 build.py:571(_make_subterm_infos)
#       110    0.001    0.000    0.174    0.002 build.py:61(_eval_factor)
#        10    0.000    0.000    0.001    0.000 build.py:638(design_matrix_builders)
#        20    0.001    0.000    0.006    0.000 build.py:739(_build_design_matrix)
#        20    0.000    0.000    0.000    0.000 build.py:775(__init__)
#       240    0.000    0.000    0.001    0.000 build.py:782(check)
#        10    0.002    0.000    0.225    0.022 build.py:797(build_design_matrices)
#       110    0.000    0.000    0.000    0.000 build.py:877(<lambda>)
#       110    0.000    0.000    0.000    0.000 build.py:878(<lambda>)
#        10    0.000    0.000    0.000    0.000 build.py:908(<listcomp>)
#       260    0.002    0.000    0.003    0.000 cast.py:1187(maybe_castable)
#      2200    0.006    0.000    0.028    0.000 cast.py:1201(maybe_infer_to_datetimelike)
#        10    0.000    0.000    0.000    0.000 cast.py:1244(try_datetime)
#        30    0.000    0.000    0.001    0.000 cast.py:1310(maybe_cast_to_datetime)
#        10    0.000    0.000    0.001    0.000 cast.py:1448(find_common_type)
#        20    0.000    0.000    0.000    0.000 cast.py:1472(<genexpr>)
#        70    0.000    0.000    0.000    0.000 cast.py:1478(<genexpr>)
#        20    0.000    0.000    0.000    0.000 cast.py:1487(<genexpr>)
#        20    0.000    0.000    0.000    0.000 cast.py:1489(<genexpr>)
#        20    0.000    0.000    0.000    0.000 cast.py:1494(<genexpr>)
#       130    0.001    0.000    0.001    0.000 cast.py:1570(construct_1d_object_array_from_listlike)
#        30    0.000    0.000    0.000    0.000 cast.py:1595(construct_1d_ndarray_preserving_na)
#        10    0.000    0.000    0.000    0.000 cast.py:1630(maybe_cast_to_integer_array)
#        20    0.000    0.000    0.001    0.000 cast.py:442(maybe_promote)
#        20    0.000    0.000    0.000    0.000 cast.py:598(_ensure_dtype_type)
#        10    0.000    0.000    0.001    0.000 cast.py:898(astype_nansafe)
#        10    0.000    0.000    0.000    0.000 categorical.py:151(_categorical_shape_fix)
#        10    0.000    0.000    0.003    0.000 categorical.py:308(categorical_to_int)
#       200    0.000    0.000    0.001    0.000 common.py:1025(is_datetime_or_timedelta_dtype)
#        10    0.000    0.000    0.000    0.000 common.py:1064(is_numeric_v_string_like)
#       200    0.000    0.000    0.003    0.000 common.py:1180(needs_i8_conversion)
#        10    0.000    0.000    0.000    0.000 common.py:1223(is_numeric_dtype)
#        10    0.000    0.000    0.000    0.000 common.py:1265(is_string_like_dtype)
#        10    0.000    0.000    0.000    0.000 common.py:1293(<lambda>)
#       480    0.000    0.000    0.001    0.000 common.py:1296(is_float_dtype)
#       700    0.001    0.000    0.005    0.000 common.py:1330(is_bool_dtype)
#      5920    0.006    0.000    0.015    0.000 common.py:1460(is_extension_array_dtype)
#       330    0.000    0.000    0.000    0.000 common.py:149(cast_scalar_indexer)
#        20    0.000    0.000    0.000    0.000 common.py:1509(is_complex_dtype)
#        10    0.000    0.000    0.000    0.000 common.py:1541(_is_dtype)
#      1050    0.001    0.000    0.001    0.000 common.py:1565(_get_dtype)
#      6010    0.007    0.000    0.013    0.000 common.py:1600(_is_dtype_type)
#      3070    0.002    0.000    0.003    0.000 common.py:1733(pandas_dtype)
#      4680    0.001    0.000    0.001    0.000 common.py:178(classes)
#      4680    0.001    0.000    0.002    0.000 common.py:180(<lambda>)
#      1330    0.000    0.000    0.000    0.000 common.py:183(classes_and_not_datetimelike)
#      1330    0.001    0.000    0.001    0.000 common.py:188(<lambda>)
#      3570    0.003    0.000    0.014    0.000 common.py:194(is_object_dtype)
#       420    0.001    0.000    0.004    0.000 common.py:218(asarray_tuplesafe)
#      3010    0.005    0.000    0.011    0.000 common.py:224(is_sparse)
#       110    0.000    0.000    0.001    0.000 common.py:274(maybe_iterable_to_list)
#        10    0.000    0.000    0.000    0.000 common.py:283(is_null_slice)
#       140    0.000    0.000    0.000    0.000 common.py:329(apply_if_callable)
#        60    0.000    0.000    0.000    0.000 common.py:348(is_datetime64_dtype)
#      3360    0.002    0.000    0.017    0.000 common.py:381(is_datetime64tz_dtype)
#       880    0.001    0.000    0.002    0.000 common.py:422(is_timedelta64_dtype)
#      4050    0.003    0.000    0.018    0.000 common.py:456(is_period_dtype)
#      3840    0.003    0.000    0.017    0.000 common.py:492(is_interval_dtype)
#       110    0.000    0.000    0.024    0.000 common.py:50(new_method)
#      4500    0.003    0.000    0.016    0.000 common.py:530(is_categorical_dtype)
#       170    0.000    0.000    0.000    0.000 common.py:608(is_dtype_equal)
#       710    0.001    0.000    0.002    0.000 common.py:696(is_integer_dtype)
#       310    0.000    0.000    0.001    0.000 common.py:750(is_signed_integer_dtype)
#       300    0.000    0.000    0.001    0.000 common.py:806(is_unsigned_integer_dtype)
#       940    0.001    0.000    0.001    0.000 common.py:905(is_datetime64_any_dtype)
#        60    0.000    0.000    0.001    0.000 common.py:97(is_bool_indexer)
#       110    0.000    0.000    0.014    0.000 compat.py:34(call_and_wrap_exc)
#       230    0.003    0.000    0.198    0.001 construction.py:143(init_ndarray)
#        10    0.002    0.000    0.030    0.003 construction.py:216(<listcomp>)
#        10    0.002    0.000    0.106    0.011 construction.py:225(<listcomp>)
#       110    0.001    0.000    0.058    0.001 construction.py:237(init_dict)
#       110    0.000    0.000    0.001    0.000 construction.py:274(<listcomp>)
#       110    0.000    0.000    0.000    0.000 construction.py:278(<listcomp>)
#       110    0.000    0.000    0.001    0.000 construction.py:281(<listcomp>)
#       230    0.000    0.000    0.001    0.000 construction.py:289(_prep_ndarray)
#       110    0.000    0.000    0.000    0.000 construction.py:329(_homogenize)
#       640    0.001    0.000    0.005    0.000 construction.py:339(extract_array)
#       110    0.001    0.000    0.001    0.000 construction.py:360(extract_index)
#       260    0.002    0.000    0.010    0.000 construction.py:390(sanitize_array)
#       230    0.000    0.000    0.005    0.000 construction.py:450(_get_axes)
#       260    0.001    0.000    0.005    0.000 construction.py:520(_try_cast)
#       260    0.000    0.000    0.001    0.000 construction.py:580(is_empty_data)
#       110    0.001    0.000    0.026    0.000 construction.py:60(arrays_to_mgr)
#        10    0.000    0.000    0.000    0.000 data.py:100(_is_using_pandas)
#        10    0.000    0.000    0.000    0.000 datetimelike.py:1082(freq)
#        10    0.000    0.000    0.000    0.000 datetimelike.py:464(_ndarray)
#        10    0.000    0.000    0.000    0.000 datetimelike.py:469(_from_backing_data)
#        10    0.000    0.000    0.000    0.000 datetimelike.py:491(asi8)
#        10    0.000    0.000    0.001    0.000 datetimelike.py:530(__getitem__)
#        10    0.000    0.000    0.000    0.000 datetimelike.py:564(_get_getitem_freq)
#        10    0.000    0.000    0.000    0.000 datetimes.py:215(__init__)
#        10    0.000    0.000    0.000    0.000 datetimes.py:2183(_validate_dt64_dtype)
#        10    0.000    0.000    0.000    0.000 datetimes.py:287(_simple_new)
#        10    0.000    0.000    0.000    0.000 datetimes.py:475(_box_func)
#        10    0.000    0.000    0.000    0.000 datetimes.py:477(<lambda>)
#        30    0.000    0.000    0.000    0.000 datetimes.py:479(dtype)
#        10    0.000    0.000    0.000    0.000 datetimes.py:501(tz)
#       240    0.000    0.000    0.000    0.000 desc.py:53(__hash__)
#        30    0.000    0.000    0.001    0.000 design_info.py:1014(__new__)
#        10    0.000    0.000    0.000    0.000 design_info.py:271(__init__)
#        10    0.000    0.000    0.000    0.000 design_info.py:361(<listcomp>)
#        80    0.000    0.000    0.000    0.000 design_info.py:401(column_names)
#       210    0.000    0.000    0.001    0.000 dispatch.py:11(should_extension_dispatch)
#      3450    0.004    0.000    0.014    0.000 dtypes.py:1119(is_dtype)
#      3660    0.003    0.000    0.014    0.000 dtypes.py:906(is_dtype)
#        10    0.000    0.000    0.000    0.000 eval.py:136(__init__)
#       110    0.000    0.000    0.014    0.000 eval.py:155(eval)
#        20    0.000    0.000    0.000    0.000 eval.py:168(capture)
#       220    0.000    0.000    0.000    0.000 eval.py:42(__init__)
#   220/110    0.000    0.000    0.010    0.000 eval.py:45(__getitem__)
#       110    0.000    0.000    0.000    0.000 eval.py:451(name)
#      1310    0.000    0.000    0.001    0.000 eval.py:464(__hash__)
#       110    0.000    0.000    0.015    0.000 eval.py:545(_eval)
#       110    0.000    0.000    0.015    0.000 eval.py:563(eval)
#        10    0.000    0.000    0.000    0.000 expressions.py:186(_has_bool_dtype)
#        10    0.000    0.000    0.000    0.000 expressions.py:195(_bool_arith_check)
#        10    0.000    0.000    0.001    0.000 expressions.py:217(evaluate)
#        10    0.000    0.000    0.000    0.000 expressions.py:61(_evaluate_standard)
#        10    0.000    0.000    0.001    0.000 expressions.py:71(_can_use_numexpr)
#        10    0.000    0.000    0.001    0.000 expressions.py:97(_evaluate_numexpr)
#        30    0.000    0.000    0.000    0.000 frame.py:1099(__len__)
#        10    0.000    0.000    0.178    0.018 frame.py:2687(transpose)
#        10    0.000    0.000    0.178    0.018 frame.py:2809(T)
#        10    0.000    0.000    0.008    0.001 frame.py:2816(_ixs)
#       100    0.000    0.000    0.006    0.000 frame.py:2854(_get_column_array)
#       200    0.000    0.000    0.006    0.000 frame.py:2861(_iter_column_arrays)
#       120    0.001    0.000    0.023    0.000 frame.py:2869(__getitem__)
#       110    0.000    0.000    0.003    0.000 frame.py:3184(_box_col_values)
#       430    0.000    0.000    0.000    0.000 frame.py:421(_constructor)
#       560    0.005    0.000    0.262    0.000 frame.py:441(__init__)
#        10    0.000    0.000    0.000    0.000 frame.py:568(axes)
#       420    0.001    0.000    0.001    0.000 frame.py:585(shape)
#       100    0.000    0.000    0.018    0.000 frame.py:5853(_combine_frame)
#       100    0.000    0.000    0.002    0.000 frame.py:5873(_construct_result)
#       110    0.000    0.000    0.002    0.000 frame.py:607(_is_homogeneous_type)
#       100    0.001    0.000    0.032    0.000 frame.py:8531(_reduce)
#       100    0.000    0.000    0.007    0.000 frame.py:8546(<listcomp>)
#       100    0.000    0.000    0.007    0.000 frame.py:8571(func)
#       100    0.000    0.000    0.000    0.000 frame.py:8883(_get_agg_axis)
#       110    0.000    0.000    0.000    0.000 fromnumeric.py:2245(_any_dispatcher)
#       110    0.000    0.000    0.035    0.000 fromnumeric.py:2249(any)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:2876(_prod_dispatcher)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:2881(prod)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:3071(_ndim_dispatcher)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:3075(ndim)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:433(_repeat_dispatcher)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:437(repeat)
#        20    0.000    0.000    0.000    0.000 fromnumeric.py:52(_wrapfunc)
#       120    0.001    0.000    0.035    0.000 fromnumeric.py:70(_wrapreduction)
#       120    0.000    0.000    0.000    0.000 fromnumeric.py:71(<dictcomp>)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:995(_argsort_dispatcher)
#        10    0.000    0.000    0.000    0.000 fromnumeric.py:999(argsort)
#       120    0.000    0.000    0.001    0.000 function.py:48(__call__)
#     63780    0.018    0.000    0.025    0.000 generic.py:10(_check)
#       100    0.001    0.000    0.034    0.000 generic.py:11562(logical_func)
#       200    0.000    0.000    0.002    0.000 generic.py:1193(_indexed_same)
#       500    0.001    0.000    0.002    0.000 generic.py:1195(<genexpr>)
#        10    0.000    0.000    0.001    0.000 generic.py:1319(__invert__)
#       310    0.000    0.000    0.006    0.000 generic.py:1780(__array__)
#       100    0.001    0.000    0.013    0.000 generic.py:1783(__array_wrap__)
#       940    0.002    0.000    0.002    0.000 generic.py:195(__init__)
#       250    0.000    0.000    0.000    0.000 generic.py:232(attrs)
#        20    0.000    0.000    0.000    0.000 generic.py:249(_validate_dtype)
#       100    0.000    0.000    0.000    0.000 generic.py:294(_data)
#       110    0.000    0.000    0.000    0.000 generic.py:3180(_set_as_cached)
#       200    0.000    0.000    0.000    0.000 generic.py:3250(_clear_item_cache)
#        10    0.000    0.000    0.005    0.000 generic.py:3256(take)
#       100    0.000    0.000    0.001    0.000 generic.py:328(_construct_axes_dict)
#       100    0.000    0.000    0.001    0.000 generic.py:330(<dictcomp>)
#        10    0.000    0.000    0.005    0.001 generic.py:3355(_take_with_is_copy)
#       110    0.001    0.000    0.008    0.000 generic.py:3534(_get_item_cache)
#        20    0.000    0.000    0.000    0.000 generic.py:3584(_set_is_copy)
#      1080    0.000    0.000    0.000    0.000 generic.py:365(_get_axis_number)
#       870    0.001    0.000    0.001    0.000 generic.py:377(_get_axis)
#        10    0.000    0.000    0.000    0.000 generic.py:382(_get_block_manager_axis)
#       130    0.000    0.000    0.000    0.000 generic.py:447(_info_axis)
#       210    0.000    0.000    0.000    0.000 generic.py:471(ndim)
#       250    0.001    0.000    0.001    0.000 generic.py:5097(__finalize__)
#      1400    0.002    0.000    0.005    0.000 generic.py:5125(__getattr__)
#      1380    0.003    0.000    0.007    0.000 generic.py:5143(__setattr__)
#       540    0.001    0.000    0.003    0.000 generic.py:5199(_protect_consolidate)
#       430    0.000    0.000    0.002    0.000 generic.py:5210(_consolidate_inplace)
#       430    0.001    0.000    0.001    0.000 generic.py:5213(f)
#       110    0.000    0.000    0.001    0.000 generic.py:5240(_is_mixed_type)
#       110    0.000    0.000    0.001    0.000 generic.py:5242(<lambda>)
#       420    0.001    0.000    0.007    0.000 generic.py:5270(values)
#       310    0.000    0.000    0.005    0.000 generic.py:5347(_values)
#        10    0.000    0.000    0.003    0.000 generic.py:5352(dtypes)
#        10    0.000    0.000    0.002    0.000 generic.py:5395(astype)
#       200    0.000    0.000    0.001    0.000 generic.py:562(_set_axis)
#        10    0.000    0.000    0.226    0.023 highlevel.py:154(_do_highlevel_design)
#        10    0.000    0.000    0.000    0.000 highlevel.py:162(data_iter_maker)
#        10    0.000    0.000    0.227    0.023 highlevel.py:225(dmatrix)
#        10    0.000    0.000    0.001    0.000 highlevel.py:33(_try_incr_builders)
#        10    0.000    0.000    0.000    0.000 indexers.py:210(maybe_convert_indices)
#        10    0.000    0.000    0.000    0.000 indexers.py:348(check_array_indexer)
#        20    0.000    0.000    0.000    0.000 indexers.py:52(is_list_like_indexer)
#        10    0.000    0.000    0.000    0.000 indexing.py:100(iloc)
#        10    0.000    0.000    0.007    0.001 indexing.py:1208(_get_listlike_indexer)
#        10    0.000    0.000    0.000    0.000 indexing.py:1257(_validate_read_indexer)
#        20    0.000    0.000    0.000    0.000 indexing.py:1334(_validate_key)
#        10    0.000    0.000    0.000    0.000 indexing.py:1400(_is_scalar_access)
#        20    0.000    0.000    0.000    0.000 indexing.py:1419(_validate_integer)
#        10    0.000    0.000    0.009    0.001 indexing.py:1441(_getitem_tuple)
#        10    0.000    0.000    0.008    0.001 indexing.py:1474(_getitem_axis)
#        10    0.000    0.000    0.000    0.000 indexing.py:2126(convert_to_index_sliceable)
#        10    0.000    0.000    0.000    0.000 indexing.py:2258(is_label_like)
#        10    0.000    0.000    0.000    0.000 indexing.py:237(loc)
#        10    0.000    0.000    0.000    0.000 indexing.py:694(_has_valid_tuple)
#        10    0.000    0.000    0.000    0.000 indexing.py:709(_is_nested_tuple_indexer)
#        30    0.000    0.000    0.000    0.000 indexing.py:715(<genexpr>)
#        10    0.000    0.000    0.008    0.001 indexing.py:757(_getitem_lowerdim)
#        10    0.000    0.000    0.009    0.001 indexing.py:864(__getitem__)
#        30    0.000    0.000    0.000    0.000 indexing.py:866(<genexpr>)
#        60    0.000    0.000    0.000    0.000 inference.py:185(is_array_like)
#        10    0.000    0.000    0.000    0.000 inference.py:263(is_dict_like)
#        20    0.000    0.000    0.000    0.000 inference.py:289(<genexpr>)
#      1440    0.001    0.000    0.001    0.000 inference.py:322(is_hashable)
#        10    0.000    0.000    0.000    0.000 inspect.py:1507(currentframe)
#        10    0.000    0.000    0.000    0.000 inspect.py:72(isclass)
#        10    0.000    0.000    0.000    0.000 linear_model.py:339(predict)
#       100    0.000    0.000    0.005    0.000 managers.py:1008(iget_values)
#        10    0.000    0.000    0.004    0.000 managers.py:1247(reindex_indexer)
#       110    0.001    0.000    0.005    0.000 managers.py:1309(_slice_take_blocks_ax0)
#       460    0.002    0.000    0.012    0.000 managers.py:132(__init__)
#       460    0.001    0.000    0.001    0.000 managers.py:138(<listcomp>)
#        10    0.000    0.000    0.005    0.000 managers.py:1436(take)
#       380    0.001    0.000    0.001    0.000 managers.py:1541(__init__)
#        20    0.000    0.000    0.000    0.000 managers.py:156(from_blocks)
#        10    0.000    0.000    0.000    0.000 managers.py:1562(from_blocks)
#       260    0.001    0.000    0.012    0.000 managers.py:1573(from_array)
#      1770    0.001    0.000    0.001    0.000 managers.py:1584(_block)
#      1000    0.001    0.000    0.002    0.000 managers.py:1611(dtype)
#       420    0.000    0.000    0.001    0.000 managers.py:1622(internal_values)
#       230    0.000    0.000    0.006    0.000 managers.py:163(blknos)
#       230    0.001    0.000    0.048    0.000 managers.py:1660(create_block_manager_from_blocks)
#       110    0.001    0.000    0.024    0.000 managers.py:1684(create_block_manager_from_arrays)
#       330    0.000    0.000    0.000    0.000 managers.py:1689(<genexpr>)
#       110    0.003    0.000    0.020    0.000 managers.py:1724(form_blocks)
#       220    0.000    0.000    0.000    0.000 managers.py:179(blklocs)
#        10    0.000    0.000    0.001    0.000 managers.py:1821(_simple_blockify)
#       100    0.001    0.000    0.010    0.000 managers.py:1836(_multi_blockify)
#       100    0.000    0.000    0.000    0.000 managers.py:1839(<lambda>)
#       110    0.001    0.000    0.003    0.000 managers.py:1852(_stack_arrays)
#       110    0.000    0.000    0.001    0.000 managers.py:1855(_asarray_compat)
#       110    0.000    0.000    0.001    0.000 managers.py:1861(_shape_compat)
#        10    0.000    0.000    0.001    0.000 managers.py:1879(_interleaved_dtype)
#        10    0.000    0.000    0.000    0.000 managers.py:1895(<listcomp>)
#        10    0.001    0.000    0.026    0.003 managers.py:1898(_consolidate)
#      4380    0.002    0.000    0.018    0.000 managers.py:1903(<lambda>)
#        20    0.000    0.000    0.007    0.000 managers.py:1915(_merge_blocks)
#        10    0.001    0.000    0.001    0.000 managers.py:1930(<listcomp>)
#        10    0.000    0.000    0.000    0.000 managers.py:1931(<listcomp>)
#       110    0.000    0.000    0.000    0.000 managers.py:2024(_preprocess_slice_or_indexer)
#       720    0.002    0.000    0.004    0.000 managers.py:212(shape)
#      2160    0.001    0.000    0.002    0.000 managers.py:214(<genexpr>)
#      2850    0.001    0.000    0.001    0.000 managers.py:216(ndim)
#       200    0.000    0.000    0.001    0.000 managers.py:220(set_axis)
#       530    0.000    0.000    0.000    0.000 managers.py:233(_is_single_block)
#       130    0.003    0.000    0.007    0.000 managers.py:238(_rebuild_blknos_and_blklocs)
#       480    0.000    0.000    0.000    0.000 managers.py:259(items)
#        10    0.000    0.000    0.001    0.000 managers.py:263(get_dtypes)
#        10    0.000    0.000    0.000    0.000 managers.py:264(<listcomp>)
#       140    0.000    0.000    0.000    0.000 managers.py:309(__len__)
#       340    0.002    0.000    0.008    0.000 managers.py:324(_verify_integrity)
#      2850    0.001    0.000    0.002    0.000 managers.py:326(<genexpr>)
#       100    0.000    0.000    0.016    0.000 managers.py:363(operate_blockwise)
#        20    0.000    0.000    0.003    0.000 managers.py:369(apply)
#        20    0.000    0.000    0.000    0.000 managers.py:388(<dictcomp>)
#        10    0.000    0.000    0.002    0.000 managers.py:601(astype)
#       900    0.001    0.000    0.003    0.000 managers.py:684(is_consolidated)
#       440    0.001    0.000    0.003    0.000 managers.py:692(_consolidate_check)
#       440    0.001    0.000    0.001    0.000 managers.py:693(<listcomp>)
#       110    0.000    0.000    0.001    0.000 managers.py:697(is_mixed_type)
#       210    0.000    0.000    0.001    0.000 managers.py:707(any_extension_types)
#       420    0.000    0.000    0.000    0.000 managers.py:710(<genexpr>)
#       420    0.002    0.000    0.004    0.000 managers.py:815(as_array)
#        10    0.001    0.000    0.006    0.001 managers.py:935(fast_xs)
#       430    0.000    0.000    0.000    0.000 managers.py:970(consolidate)
#       470    0.001    0.000    0.030    0.000 managers.py:986(_consolidate_inplace)
#       110    0.001    0.000    0.003    0.000 managers.py:993(iget)
#       100    0.001    0.000    0.023    0.000 methods.py:95(f)
#        10    0.000    0.000    0.000    0.000 missing.py:119(is_categorical_NA)
#       100    0.003    0.000    0.091    0.001 missing.py:129(is_numerical_NA)
#        30    0.000    0.000    0.000    0.000 missing.py:130(_isna)
#        10    0.000    0.000    0.000    0.000 missing.py:136(dispatch_fill_zeros)
#        10    0.000    0.000    0.030    0.003 missing.py:141(handle_NA)
#        10    0.000    0.000    0.030    0.003 missing.py:175(_handle_NA_drop)
#        10    0.001    0.000    0.003    0.000 missing.py:181(<listcomp>)
#        20    0.000    0.000    0.000    0.000 missing.py:358(array_equivalent)
#        30    0.000    0.000    0.000    0.000 missing.py:47(isna)
#        20    0.000    0.000    0.000    0.000 missing.py:665(clean_reindex_fill_method)
#        20    0.000    0.000    0.000    0.000 missing.py:75(clean_fill_method)
#        20    0.000    0.000    0.000    0.000 missing.py:88(__init__)
#        10    0.000    0.000    0.229    0.023 model.py:950(predict)
#        20    0.000    0.000    0.000    0.000 multiarray.py:143(concatenate)
#        20    0.000    0.000    0.000    0.000 multiarray.py:468(can_cast)
#        10    0.000    0.000    0.000    0.000 multiarray.py:706(dot)
#       100    0.000    0.000    0.000    0.000 nanops.py:168(_get_fill_value)
#       100    0.000    0.000    0.001    0.000 nanops.py:193(_maybe_get_mask)
#       100    0.001    0.000    0.006    0.000 nanops.py:237(_get_values)
#       100    0.000    0.000    0.001    0.000 nanops.py:322(_na_ok_dtype)
#       100    0.000    0.000    0.007    0.000 nanops.py:396(nanany)
#        10    0.000    0.000    0.000    0.000 numeric.py:105(_shallow_copy)
#       360    0.000    0.000    0.000    0.000 numeric.py:150(is_all_dates)
#        10    0.000    0.000    0.000    0.000 numeric.py:2313(_array_equal_dispatcher)
#        10    0.000    0.000    0.000    0.000 numeric.py:2317(array_equal)
#        10    0.000    0.000    0.000    0.000 numeric.py:50(__new__)
#        10    0.000    0.000    0.000    0.000 numeric.py:81(_validate_dtype)
#       560    0.001    0.000    0.001    0.000 numerictypes.py:286(issubclass_)
#       280    0.000    0.000    0.001    0.000 numerictypes.py:360(issubdtype)
#       350    0.001    0.000    0.001    0.000 numpy_.py:162(__init__)
#       140    0.000    0.000    0.000    0.000 numpy_.py:210(__array__)
#       210    0.000    0.000    0.000    0.000 numpy_.py:414(to_numpy)
#       350    0.000    0.000    0.000    0.000 numpy_.py:50(__init__)
#       100    0.001    0.000    0.016    0.000 ops.py:12(operate_blockwise)
#       100    0.000    0.000    0.002    0.000 ops.py:64(_reset_block_mgr_locs)
#       100    0.000    0.000    0.000    0.000 ops.py:76(_get_same_shape_values)
#        10    0.000    0.000    0.000    0.000 random.py:174(randrange)
#        10    0.000    0.000    0.000    0.000 random.py:218(randint)
#        10    0.000    0.000    0.000    0.000 random.py:224(_randbelow)
#        30    0.000    0.000    0.000    0.000 range.py:687(__len__)
#        10    0.000    0.000    0.000    0.000 range.py:697(__getitem__)
#       100    0.000    0.000    0.001    0.000 roperator.py:55(ror_)
#       380    0.003    0.000    0.033    0.000 series.py:201(__init__)
#       110    0.000    0.000    0.013    0.000 series.py:2741(_construct_result)
#       130    0.000    0.000    0.000    0.000 series.py:381(_constructor)
#       370    0.001    0.000    0.001    0.000 series.py:398(_set_axis)
#      1000    0.001    0.000    0.002    0.000 series.py:427(dtype)
#      1320    0.001    0.000    0.002    0.000 series.py:442(name)
#       610    0.001    0.000    0.001    0.000 series.py:492(name)
#       420    0.000    0.000    0.001    0.000 series.py:540(_values)
#       350    0.000    0.000    0.002    0.000 series.py:574(array)
#       130    0.000    0.000    0.001    0.000 series.py:595(__len__)
#        10    0.000    0.000    0.002    0.000 series.py:675(__array_ufunc__)
#        10    0.000    0.000    0.000    0.000 series.py:705(<listcomp>)
#        30    0.000    0.000    0.000    0.000 series.py:706(<genexpr>)
#        10    0.000    0.000    0.000    0.000 series.py:708(<listcomp>)
#        30    0.000    0.000    0.000    0.000 series.py:725(<genexpr>)
#        10    0.000    0.000    0.001    0.000 series.py:730(construct_return)
#       140    0.000    0.000    0.002    0.000 series.py:750(__array__)
#        30    0.000    0.000    0.000    0.000 shape_base.py:20(_atleast_1d_dispatcher)
#        10    0.000    0.000    0.000    0.000 shape_base.py:208(_arrays_for_stack_dispatcher)
#        10    0.000    0.000    0.000    0.000 shape_base.py:219(_vhstack_dispatcher)
#        10    0.000    0.000    0.003    0.000 shape_base.py:223(vstack)
#        30    0.000    0.000    0.000    0.000 shape_base.py:24(atleast_1d)
#        20    0.000    0.000    0.000    0.000 shape_base.py:78(_atleast_2d_dispatcher)
#        20    0.001    0.000    0.002    0.000 shape_base.py:82(atleast_2d)
#        40    0.000    0.000    0.000    0.000 six.py:585(itervalues)
#       120    0.000    0.000    0.000    0.000 six.py:588(iteritems)
#       130    0.000    0.000    0.053    0.000 util.py:159(atleast_2d_column_default)
#        10    0.000    0.000    0.000    0.000 util.py:556(safe_scalar_isnan)
#        10    0.000    0.000    0.000    0.000 util.py:583(iterable)
#       180    0.000    0.000    0.001    0.000 util.py:669(safe_is_pandas_categorical_dtype)
#        10    0.000    0.000    0.000    0.000 util.py:675(safe_is_pandas_categorical)
#       170    0.000    0.000    0.002    0.000 util.py:707(safe_issubdtype)
#        10    0.000    0.000    0.000    0.000 warnings.py:165(simplefilter)
#        10    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#        10    0.000    0.000    0.000    0.000 warnings.py:449(__init__)
#        10    0.000    0.000    0.000    0.000 warnings.py:470(__enter__)
#        10    0.000    0.000    0.000    0.000 warnings.py:489(__exit__)
#     20/10    0.000    0.000    0.000    0.000 wrapper.py:22(__getattribute__)
#        40    0.000    0.000    0.000    0.000 wrapper.py:23(<lambda>)
#       280    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x558bd73bbd40}
#      3510    0.002    0.000    0.002    0.000 {built-in method _abc._abc_instancecheck}
#        10    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#        10    0.000    0.000    0.000    0.000 {built-in method _operator.eq}
#        10    0.000    0.000    0.000    0.000 {built-in method _operator.invert}
#       200    0.001    0.000    0.001    0.000 {built-in method _operator.or_}
#        30    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#       460    0.000    0.000    0.003    0.000 {built-in method builtins.all}
#       240    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#       160    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       110    0.003    0.000    0.003    0.000 {built-in method builtins.compile}
#       110    0.000    0.000    0.011    0.000 {built-in method builtins.eval}
#         1    0.000    0.000    0.440    0.440 {built-in method builtins.exec}
# 89660/89640    0.011    0.000    0.012    0.000 {built-in method builtins.getattr}
#     11870    0.003    0.000    0.004    0.000 {built-in method builtins.hasattr}
#      3220    0.001    0.000    0.001    0.000 {built-in method builtins.hash}
#    115490    0.036    0.000    0.062    0.000 {built-in method builtins.isinstance}
#     36750    0.005    0.000    0.005    0.000 {built-in method builtins.issubclass}
#       180    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 29950/25100    0.011    0.000    0.013    0.000 {built-in method builtins.len}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        10    0.001    0.000    0.010    0.001 {built-in method builtins.sorted}
#       340    0.001    0.000    0.003    0.000 {built-in method builtins.sum}
#        10    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#       250    0.001    0.000    0.001    0.000 {built-in method numpy.arange}
# 9310/8730    0.013    0.000    0.019    0.000 {built-in method numpy.array}
#   270/250    0.003    0.000    0.041    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        20    0.000    0.000    0.000    0.000 {built-in method numpy.datetime_data}
#       580    0.003    0.000    0.003    0.000 {built-in method numpy.empty}
#       120    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#        60    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#       120    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#       100    0.000    0.000    0.000    0.000 {built-in method pandas._libs.internals.slice_len}
#        30    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#        10    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslib.array_to_datetime}
#        10    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#        20    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#       260    0.000    0.000    0.002    0.000 {method 'any' of 'numpy.ndarray' objects}
#      2910    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#        10    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#       420    0.001    0.000    0.001    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#       200    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#       100    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#       210    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#       260    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#       110    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       380    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        20    0.000    0.000    0.000    0.000 {method 'get_indexer' of 'pandas._libs.index.IndexEngine' objects}
#       110    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#        12    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#        10    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#        70    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#       170    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#       120    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#        10    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        20    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       320    0.002    0.000    0.002    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        10    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        10    0.000    0.000    0.000    0.000 {method 'repeat' of 'numpy.ndarray' objects}
#      2430    0.002    0.000    0.002    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        20    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#        10    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#       420    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#       100    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#      2410    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        40    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#        40    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#        50    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#        40    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_int64}
#      2190    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_object}
#        40    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#        20    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_int64_int64}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_object_object}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis1_object_object}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.lib.astype_intsafe}
#        20    0.000    0.000    0.000    0.000 {pandas._libs.lib.clean_index_list}
#      2190    0.001    0.000    0.001    0.000 {pandas._libs.lib.infer_datetimelike_array}
#       190    0.002    0.000    0.003    0.000 {pandas._libs.lib.infer_dtype}
#       120    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#       350    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#        80    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#       190    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#      3280    0.003    0.000    0.005    0.000 {pandas._libs.lib.is_list_like}
#       650    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#       650    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#        10    0.000    0.000    0.000    0.000 {pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op}
